# %% [markdown]
# Notes, thoughts, and analysis:
#
# I first tested out the process with one single pdp. (blocks 1-5). Then I implemented a crawler (block 6). I found filtering and parsing the information from the crawler too complicated to implement by hand. So I chose 20 webpages to form a larger document for testing purposes.(block 7 and 8)
#
# I implemented the chat functionality with two libraries: a question-answering BERT model, and langchain. I have not carried out comprehensive testings, but langchain performs better overall. langchain performs relatively better on questions about recommendation than about product details.
#
# In the future we might face a design choice between optimizing the accuracy of answering questions on details, or giving contextual recommendations. I am not familiar with webpage indexing so I would like to know which should have more weight. For the former, we could fine-tune the model. For the latter, we could retrieve more info about related products from the pdps.

# %% [markdown]
# ### 1. Get contents from a single webpage

# %%
import requests
from bs4 import BeautifulSoup
import json

url = 'https://www.jcrew.com/p/womens/categories/clothing/blazers/lady-jacket/odette-sweater-lady-jacket-in-cotton-blend-boucleacute/BR789?display=standard&fit=Classic&color_name=kelly-green&colorProductCode=BR789'
response = requests.get(url)
html_content = response.text

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, 'html.parser')

# hard coded, locate useful info about product
allTags = soup.find_all('script')
descriptionStr = None
for tag in allTags:
    if tag.string and tag.string.strip():
        descriptionStr = tag.string.strip()
descriptionDict = json.loads(descriptionStr)['props']['initialState']['products']['productsByProductCode']

# %% [markdown]
# ### 2. View the data

# %%
def print_nested_dict_keys(d, prefix=""):
    for k, v in d.items():
        if isinstance(v, dict):
            print_nested_dict_keys(v, prefix + k + ".")
        else:
            print(prefix + k + str(v))
print_nested_dict_keys(descriptionDict)
# Out:
# BR789.productCodeBR789
# BR789.productDataFetchedFalse
# BR789.lastUpdated0
# BR789.deliveryMethod
# BR789.variationProductCodeNone
# BR789.productNameOdette sweater lady jacket in cotton-blend boucl&eacute;
# BR789.pdpIntlMessage
# BR789.isPreorderTrue
# BR789.isProductOutOfStockFalse
# BR789.shipRestrictedFalse
# BR789.isFindInStoreFalse
# BR789.styledWithSkus
# BR789.shopTheLookItems[]
# BR789.swatchOrderAlphabeticalFalse
# BR789.isFreeShippingFalse
# BR789.brand
# BR789.brandLink
# BR789.marketplaceAttributesNone
# BR789.sizeChart1,0
# BR789.url/p/womens/categories/clothing/blazers/lady-jacket/odette-sweater-lady-jacket-in-cotton-blend-boucleacute/BR789?display=standard
# BR789.promoTextNone
# BR789.excludePromoTrue
# BR789.defaultColorName
# BR789.baseProductCodeBR789
# BR789.defaultColorCode
# BR789.baseProductColorCode
# BR789.shotTypes['eiec']
# BR789.genderwomen
# BR789.productDescriptionRomanceSomewhere between a jacket and a cardigan, this easy layer is perfect for days that feel somewhere between seasons. Featuring a crochet trim, gold button details and hook-and-eye closures, this sweet style is soft, snug and chic.
# BR789.productDescriptionTech['70% cotton/30% polyamide.', 'Machine wash.', 'Import.']
# BR789.productDescriptionFit['Cropped fit.', 'Hits slightly above hip.', 'Body length: 18 3/4".', 'Sleeve length: 30".']
# BR789.seoProperties.titleJ.Crew: Odette sweater lady jacket in cotton-blend boucl&eacute; for women
# BR789.seoProperties.descriptionShop  for the Odette sweater lady jacket in cotton-blend boucl&eacute; for women. Find the best selection of women womens-categories-clothing-blazers-lady-jacket available in-stores and on line.
# BR789.seoProperties.sidecarCanonicalUrl/p/womens/categories/clothing/blazers/lady-jacket/odette-sweater-lady-jacket-in-cotton-blend-boucleacute/BR789
# BR789.personalizationDetail.monogramNone
# BR789.personalizationDetail.embossNone
# BR789.styleWarmth
# BR789.styleStretch
# BR789.fitModelDetails[]
# BR789.variations[]
# BR789.c_styleEco[]
# BR789.maxOrderableQuantity9
# BR789.listPrice.amount178
# BR789.listPrice.formatted$178.00
# BR789.colorsList[{'price': {'amount': 178, 'formatted': '$178.00'}, 'colors': [{'productCode': 'BR789', 'code': 'YL5659', 'name': 'CRISP YELLOW'}, {'productCode': 'BR789', 'code': 'WT0002', 'name': 'WHITE'}, {'productCode': 'BR789', 'code': 'GR8019', 'name': 'KELLY GREEN'}, {'productCode': 'BR789', 'code': 'BL7505', 'name': 'MEDITERRANEAN NAVY'}]}]
# BR789.sizesMap.X-LARGE.WT000299107074762
# BR789.sizesMap.X-LARGE.YL565999107074773
# BR789.sizesMap.X-LARGE.BL750599107074729
# BR789.sizesMap.X-LARGE.GR801999107074740
# BR789.sizesMap.X-SMALL.WT000299107074763
# BR789.sizesMap.X-SMALL.BL750599107074730
# BR789.sizesMap.X-SMALL.GR801999107074741
# BR789.sizesMap.X-SMALL.YL565999107074774
# BR789.sizesMap.SMALL.WT000299107074761
# BR789.sizesMap.SMALL.GR801999107074739
# BR789.sizesMap.SMALL.BL750599107074728
# BR789.sizesMap.SMALL.YL565999107074772
# BR789.sizesMap.XX-LARGE.WT000299107074764
# BR789.sizesMap.XX-LARGE.YL565999107074775
# BR789.sizesMap.XX-LARGE.BL750599107074731
# BR789.sizesMap.XX-LARGE.GR801999107074742
# BR789.sizesMap.MEDIUM.WT000299107074759
# BR789.sizesMap.MEDIUM.GR801999107074737
# BR789.sizesMap.MEDIUM.BL750599107074726
# BR789.sizesMap.MEDIUM.YL565999107074770
# BR789.sizesMap.2X.YL565999107074767
# BR789.sizesMap.2X.BL750599107074723
# BR789.sizesMap.2X.WT000299107074756
# BR789.sizesMap.2X.GR801999107074734
# BR789.sizesMap.3X.BL750599107074724
# BR789.sizesMap.3X.GR801999107074735
# BR789.sizesMap.3X.WT000299107074757
# BR789.sizesMap.3X.YL565999107074768
# BR789.sizesMap.XX-SMALL.GR801999107074743
# BR789.sizesMap.XX-SMALL.BL750599107074732
# BR789.sizesMap.XX-SMALL.WT000299107074765
# BR789.sizesMap.XX-SMALL.YL565999107074776
# BR789.sizesMap.LARGE.YL565999107074769
# BR789.sizesMap.LARGE.GR801999107074736
# BR789.sizesMap.LARGE.BL750599107074725
# BR789.sizesMap.LARGE.WT000299107074758
# BR789.colorsMap.WT0002.X-LARGE99107074762
# BR789.colorsMap.WT0002.X-SMALL99107074763
# BR789.colorsMap.WT0002.SMALL99107074761
# BR789.colorsMap.WT0002.XX-LARGE99107074764
# BR789.colorsMap.WT0002.MEDIUM99107074759
# BR789.colorsMap.WT0002.3X99107074757
# BR789.colorsMap.WT0002.XX-SMALL99107074765
# BR789.colorsMap.WT0002.LARGE99107074758
# BR789.colorsMap.WT0002.2X99107074756
# BR789.colorsMap.YL5659.X-LARGE99107074773
# BR789.colorsMap.YL5659.2X99107074767
# BR789.colorsMap.YL5659.XX-LARGE99107074775
# BR789.colorsMap.YL5659.LARGE99107074769
# BR789.colorsMap.YL5659.3X99107074768
# BR789.colorsMap.YL5659.X-SMALL99107074774
# BR789.colorsMap.YL5659.MEDIUM99107074770
# BR789.colorsMap.YL5659.XX-SMALL99107074776
# BR789.colorsMap.YL5659.SMALL99107074772
# BR789.colorsMap.BL7505.X-SMALL99107074730
# BR789.colorsMap.BL7505.3X99107074724
# BR789.colorsMap.BL7505.X-LARGE99107074729
# BR789.colorsMap.BL7505.XX-LARGE99107074731
# BR789.colorsMap.BL7505.XX-SMALL99107074732
# BR789.colorsMap.BL7505.LARGE99107074725
# BR789.colorsMap.BL7505.2X99107074723
# BR789.colorsMap.BL7505.MEDIUM99107074726
# BR789.colorsMap.BL7505.SMALL99107074728
# BR789.colorsMap.GR8019.3X99107074735
# BR789.colorsMap.GR8019.XX-SMALL99107074743
# BR789.colorsMap.GR8019.X-LARGE99107074740
# BR789.colorsMap.GR8019.LARGE99107074736
# BR789.colorsMap.GR8019.SMALL99107074739
# BR789.colorsMap.GR8019.MEDIUM99107074737
# BR789.colorsMap.GR8019.X-SMALL99107074741
# BR789.colorsMap.GR8019.XX-LARGE99107074742
# BR789.colorsMap.GR8019.2X99107074734
# BR789.skus.99107074762.colorCodeWT0002
# BR789.skus.99107074762.colorNameWHITE
# BR789.skus.99107074762.sizeCodeXL
# BR789.skus.99107074762.sizeX-LARGE
# BR789.skus.99107074762.orderableTrue
# BR789.skus.99107074762.price.amount178
# BR789.skus.99107074762.price.formatted$178.00
# BR789.skus.99107074763.colorCodeWT0002
# BR789.skus.99107074763.colorNameWHITE
# BR789.skus.99107074763.sizeCodeXS
# BR789.skus.99107074763.sizeX-SMALL
# BR789.skus.99107074763.orderableTrue
# BR789.skus.99107074763.price.amount178
# BR789.skus.99107074763.price.formatted$178.00
# BR789.skus.99107074761.colorCodeWT0002
# BR789.skus.99107074761.colorNameWHITE
# BR789.skus.99107074761.sizeCodeS
# BR789.skus.99107074761.sizeSMALL
# BR789.skus.99107074761.orderableTrue
# BR789.skus.99107074761.price.amount178
# BR789.skus.99107074761.price.formatted$178.00
# BR789.skus.99107074764.colorCodeWT0002
# BR789.skus.99107074764.colorNameWHITE
# BR789.skus.99107074764.sizeCodeXXL
# BR789.skus.99107074764.sizeXX-LARGE
# BR789.skus.99107074764.orderableTrue
# BR789.skus.99107074764.price.amount178
# BR789.skus.99107074764.price.formatted$178.00
# BR789.skus.99107074759.colorCodeWT0002
# BR789.skus.99107074759.colorNameWHITE
# BR789.skus.99107074759.sizeCodeM
# BR789.skus.99107074759.sizeMEDIUM
# BR789.skus.99107074759.orderableTrue
# BR789.skus.99107074759.price.amount178
# BR789.skus.99107074759.price.formatted$178.00
# BR789.skus.99107074773.colorCodeYL5659
# BR789.skus.99107074773.colorNameCRISP YELLOW
# BR789.skus.99107074773.sizeCodeXL
# BR789.skus.99107074773.sizeX-LARGE
# BR789.skus.99107074773.orderableTrue
# BR789.skus.99107074773.price.amount178
# BR789.skus.99107074773.price.formatted$178.00
# BR789.skus.99107074767.colorCodeYL5659
# BR789.skus.99107074767.colorNameCRISP YELLOW
# BR789.skus.99107074767.sizeCode2X
# BR789.skus.99107074767.size2X
# BR789.skus.99107074767.orderableTrue
# BR789.skus.99107074767.price.amount178
# BR789.skus.99107074767.price.formatted$178.00
# BR789.skus.99107074730.colorCodeBL7505
# BR789.skus.99107074730.colorNameMEDITERRANEAN NAVY
# BR789.skus.99107074730.sizeCodeXS
# BR789.skus.99107074730.sizeX-SMALL
# BR789.skus.99107074730.orderableTrue
# BR789.skus.99107074730.price.amount178
# BR789.skus.99107074730.price.formatted$178.00
# BR789.skus.99107074724.colorCodeBL7505
# BR789.skus.99107074724.colorNameMEDITERRANEAN NAVY
# BR789.skus.99107074724.sizeCode3X
# BR789.skus.99107074724.size3X
# BR789.skus.99107074724.orderableTrue
# BR789.skus.99107074724.price.amount178
# BR789.skus.99107074724.price.formatted$178.00
# BR789.skus.99107074775.colorCodeYL5659
# BR789.skus.99107074775.colorNameCRISP YELLOW
# BR789.skus.99107074775.sizeCodeXXL
# BR789.skus.99107074775.sizeXX-LARGE
# BR789.skus.99107074775.orderableTrue
# BR789.skus.99107074775.price.amount178
# BR789.skus.99107074775.price.formatted$178.00
# BR789.skus.99107074729.colorCodeBL7505
# BR789.skus.99107074729.colorNameMEDITERRANEAN NAVY
# BR789.skus.99107074729.sizeCodeXL
# BR789.skus.99107074729.sizeX-LARGE
# BR789.skus.99107074729.orderableTrue
# BR789.skus.99107074729.price.amount178
# BR789.skus.99107074729.price.formatted$178.00
# BR789.skus.99107074735.colorCodeGR8019
# BR789.skus.99107074735.colorNameKELLY GREEN
# BR789.skus.99107074735.sizeCode3X
# BR789.skus.99107074735.size3X
# BR789.skus.99107074735.orderableTrue
# BR789.skus.99107074735.price.amount178
# BR789.skus.99107074735.price.formatted$178.00
# BR789.skus.99107074743.colorCodeGR8019
# BR789.skus.99107074743.colorNameKELLY GREEN
# BR789.skus.99107074743.sizeCodeXXS
# BR789.skus.99107074743.sizeXX-SMALL
# BR789.skus.99107074743.orderableTrue
# BR789.skus.99107074743.price.amount178
# BR789.skus.99107074743.price.formatted$178.00
# BR789.skus.99107074757.colorCodeWT0002
# BR789.skus.99107074757.colorNameWHITE
# BR789.skus.99107074757.sizeCode3X
# BR789.skus.99107074757.size3X
# BR789.skus.99107074757.orderableTrue
# BR789.skus.99107074757.price.amount178
# BR789.skus.99107074757.price.formatted$178.00
# BR789.skus.99107074769.colorCodeYL5659
# BR789.skus.99107074769.colorNameCRISP YELLOW
# BR789.skus.99107074769.sizeCodeL
# BR789.skus.99107074769.sizeLARGE
# BR789.skus.99107074769.orderableTrue
# BR789.skus.99107074769.price.amount178
# BR789.skus.99107074769.price.formatted$178.00
# BR789.skus.99107074740.colorCodeGR8019
# BR789.skus.99107074740.colorNameKELLY GREEN
# BR789.skus.99107074740.sizeCodeXL
# BR789.skus.99107074740.sizeX-LARGE
# BR789.skus.99107074740.orderableTrue
# BR789.skus.99107074740.price.amount178
# BR789.skus.99107074740.price.formatted$178.00
# BR789.skus.99107074736.colorCodeGR8019
# BR789.skus.99107074736.colorNameKELLY GREEN
# BR789.skus.99107074736.sizeCodeL
# BR789.skus.99107074736.sizeLARGE
# BR789.skus.99107074736.orderableTrue
# BR789.skus.99107074736.price.amount178
# BR789.skus.99107074736.price.formatted$178.00
# BR789.skus.99107074731.colorCodeBL7505
# BR789.skus.99107074731.colorNameMEDITERRANEAN NAVY
# BR789.skus.99107074731.sizeCodeXXL
# BR789.skus.99107074731.sizeXX-LARGE
# BR789.skus.99107074731.orderableTrue
# BR789.skus.99107074731.price.amount178
# BR789.skus.99107074731.price.formatted$178.00
# BR789.skus.99107074732.colorCodeBL7505
# BR789.skus.99107074732.colorNameMEDITERRANEAN NAVY
# BR789.skus.99107074732.sizeCodeXXS
# BR789.skus.99107074732.sizeXX-SMALL
# BR789.skus.99107074732.orderableTrue
# BR789.skus.99107074732.price.amount178
# BR789.skus.99107074732.price.formatted$178.00
# BR789.skus.99107074725.colorCodeBL7505
# BR789.skus.99107074725.colorNameMEDITERRANEAN NAVY
# BR789.skus.99107074725.sizeCodeL
# BR789.skus.99107074725.sizeLARGE
# BR789.skus.99107074725.orderableTrue
# BR789.skus.99107074725.price.amount178
# BR789.skus.99107074725.price.formatted$178.00
# BR789.skus.99107074739.colorCodeGR8019
# BR789.skus.99107074739.colorNameKELLY GREEN
# BR789.skus.99107074739.sizeCodeS
# BR789.skus.99107074739.sizeSMALL
# BR789.skus.99107074739.orderableTrue
# BR789.skus.99107074739.price.amount178
# BR789.skus.99107074739.price.formatted$178.00
# BR789.skus.99107074765.colorCodeWT0002
# BR789.skus.99107074765.colorNameWHITE
# BR789.skus.99107074765.sizeCodeXXS
# BR789.skus.99107074765.sizeXX-SMALL
# BR789.skus.99107074765.orderableTrue
# BR789.skus.99107074765.price.amount178
# BR789.skus.99107074765.price.formatted$178.00
# BR789.skus.99107074723.colorCodeBL7505
# BR789.skus.99107074723.colorNameMEDITERRANEAN NAVY
# BR789.skus.99107074723.sizeCode2X
# BR789.skus.99107074723.size2X
# BR789.skus.99107074723.orderableTrue
# BR789.skus.99107074723.price.amount178
# BR789.skus.99107074723.price.formatted$178.00
# BR789.skus.99107074737.colorCodeGR8019
# BR789.skus.99107074737.colorNameKELLY GREEN
# BR789.skus.99107074737.sizeCodeM
# BR789.skus.99107074737.sizeMEDIUM
# BR789.skus.99107074737.orderableTrue
# BR789.skus.99107074737.price.amount178
# BR789.skus.99107074737.price.formatted$178.00
# BR789.skus.99107074758.colorCodeWT0002
# BR789.skus.99107074758.colorNameWHITE
# BR789.skus.99107074758.sizeCodeL
# BR789.skus.99107074758.sizeLARGE
# BR789.skus.99107074758.orderableTrue
# BR789.skus.99107074758.price.amount178
# BR789.skus.99107074758.price.formatted$178.00
# BR789.skus.99107074741.colorCodeGR8019
# BR789.skus.99107074741.colorNameKELLY GREEN
# BR789.skus.99107074741.sizeCodeXS
# BR789.skus.99107074741.sizeX-SMALL
# BR789.skus.99107074741.orderableTrue
# BR789.skus.99107074741.price.amount178
# BR789.skus.99107074741.price.formatted$178.00
# BR789.skus.99107074768.colorCodeYL5659
# BR789.skus.99107074768.colorNameCRISP YELLOW
# BR789.skus.99107074768.sizeCode3X
# BR789.skus.99107074768.size3X
# BR789.skus.99107074768.orderableTrue
# BR789.skus.99107074768.price.amount178
# BR789.skus.99107074768.price.formatted$178.00
# BR789.skus.99107074774.colorCodeYL5659
# BR789.skus.99107074774.colorNameCRISP YELLOW
# BR789.skus.99107074774.sizeCodeXS
# BR789.skus.99107074774.sizeX-SMALL
# BR789.skus.99107074774.orderableTrue
# BR789.skus.99107074774.price.amount178
# BR789.skus.99107074774.price.formatted$178.00
# BR789.skus.99107074726.colorCodeBL7505
# BR789.skus.99107074726.colorNameMEDITERRANEAN NAVY
# BR789.skus.99107074726.sizeCodeM
# BR789.skus.99107074726.sizeMEDIUM
# BR789.skus.99107074726.orderableTrue
# BR789.skus.99107074726.price.amount178
# BR789.skus.99107074726.price.formatted$178.00
# BR789.skus.99107074756.colorCodeWT0002
# BR789.skus.99107074756.colorNameWHITE
# BR789.skus.99107074756.sizeCode2X
# BR789.skus.99107074756.size2X
# BR789.skus.99107074756.orderableTrue
# BR789.skus.99107074756.price.amount178
# BR789.skus.99107074756.price.formatted$178.00
# BR789.skus.99107074728.colorCodeBL7505
# BR789.skus.99107074728.colorNameMEDITERRANEAN NAVY
# BR789.skus.99107074728.sizeCodeS
# BR789.skus.99107074728.sizeSMALL
# BR789.skus.99107074728.orderableTrue
# BR789.skus.99107074728.price.amount178
# BR789.skus.99107074728.price.formatted$178.00
# BR789.skus.99107074742.colorCodeGR8019
# BR789.skus.99107074742.colorNameKELLY GREEN
# BR789.skus.99107074742.sizeCodeXXL
# BR789.skus.99107074742.sizeXX-LARGE
# BR789.skus.99107074742.orderableTrue
# BR789.skus.99107074742.price.amount178
# BR789.skus.99107074742.price.formatted$178.00
# BR789.skus.99107074734.colorCodeGR8019
# BR789.skus.99107074734.colorNameKELLY GREEN
# BR789.skus.99107074734.sizeCode2X
# BR789.skus.99107074734.size2X
# BR789.skus.99107074734.orderableTrue
# BR789.skus.99107074734.price.amount178
# BR789.skus.99107074734.price.formatted$178.00
# BR789.skus.99107074770.colorCodeYL5659
# BR789.skus.99107074770.colorNameCRISP YELLOW
# BR789.skus.99107074770.sizeCodeM
# BR789.skus.99107074770.sizeMEDIUM
# BR789.skus.99107074770.orderableTrue
# BR789.skus.99107074770.price.amount178
# BR789.skus.99107074770.price.formatted$178.00
# BR789.skus.99107074776.colorCodeYL5659
# BR789.skus.99107074776.colorNameCRISP YELLOW
# BR789.skus.99107074776.sizeCodeXXS
# BR789.skus.99107074776.sizeXX-SMALL
# BR789.skus.99107074776.orderableTrue
# BR789.skus.99107074776.price.amount178
# BR789.skus.99107074776.price.formatted$178.00
# BR789.skus.99107074772.colorCodeYL5659
# BR789.skus.99107074772.colorNameCRISP YELLOW
# BR789.skus.99107074772.sizeCodeS
# BR789.skus.99107074772.sizeSMALL
# BR789.skus.99107074772.orderableTrue
# BR789.skus.99107074772.price.amount178
# BR789.skus.99107074772.price.formatted$178.00
# BR789.sizesList['XXX-SMALL', 'XX-SMALL', 'X-SMALL', 'SMALL', 'MEDIUM', 'LARGE', 'X-LARGE', 'XX-LARGE', '2X', '3X']
# BR789.promoMessageOverride
# BR789.analyticsData.colors.total4
# BR789.analyticsData.colors.available4
# BR789.analyticsData.sizes.total10
# BR789.analyticsData.sizes.available9
# BR789.primaryCategoryIdwomens|categories|clothing|blazers|lady-jacket
# BR789.moreToSeeWidgetDataNone
# BR789.displaystandard
# BR789.color_namekelly-green
# BR789.colorProductCodeBR789
# BR789.mergedp
# BR789.categoryAndProductPathcategories/clothing/blazers/lady-jacket/odette-sweater-lady-jacket-in-cotton-blend-boucleacute
# BR789.colorNameKELLY GREEN
# BR789.selectedColorProductCodeBR789
# BR789.selectedQuantity1
# BR789.selectedColorNameKELLY GREEN
# BR789.selectedColorCodeGR8019
# BR789.selectedProductCodeBR789
# BR789.selectedSize
# BR789.isEditFalse
# BR789.isStoresShowAllTrue
# BR789.isMergedFalse
# BR789.priceModel.BR789.listPrice.amount178
# BR789.priceModel.BR789.listPrice.formatted$178.00
# BR789.priceModel.BR789.colors[{'salePrice': {'amount': 178, 'formatted': '$178.00'}, 'colorName': 'WHITE', 'colorCode': 'WT0002', 'skuShotType': '_m,_d1,_d2', 'hasOnfig': True, 'shot-type': ''}, {'salePrice': {'amount': 178, 'formatted': '$178.00'}, 'colorName': 'CRISP YELLOW', 'colorCode': 'YL5659', 'skuShotType': '_m,_d1,_d2', 'hasOnfig': True, 'shot-type': ''}, {'salePrice': {'amount': 178, 'formatted': '$178.00'}, 'colorName': 'MEDITERRANEAN NAVY', 'colorCode': 'BL7505', 'skuShotType': '_m,_d1,_d2', 'hasOnfig': True, 'shot-type': ''}, {'salePrice': {'amount': 178, 'formatted': '$178.00'}, 'colorName': 'KELLY GREEN', 'colorCode': 'GR8019', 'skuShotType': '_m,_d1,_d2,_d3', 'hasOnfig': True, 'shot-type': ''}]
# BR789.priceModel.BR789.badge.typeTS
# BR789.priceModel.BR789.badge.labelbest seller
# BR789.priceModel.BR789.badge.iconTS
# BR789.priceModel.BR789.badge.iconPathTS
# BR789.priceModel.BR789.badge.debug_data.fitTypeClassic
# BR789.priceModel.BR789.badge.debug_data.displayOnstandard_usd
# BR789.priceModel.BR789.badge.debug_data.orderableColors.BL7505MEDITERRANEAN NAVY
# BR789.priceModel.BR789.badge.debug_data.orderableColors.GR8019KELLY GREEN
# BR789.priceModel.BR789.badge.debug_data.orderableColors.WT0002WHITE
# BR789.priceModel.BR789.badge.debug_data.orderableColors.YL5659CRISP YELLOW
# BR789.priceModel.BR789.badge.debug_data.lowInventoryStatusNone
# BR789.hasVariationsFalse

# %% [markdown]
# ### 3. Use Depth First Search, load selected tags and values

# %%
# Ignored related products for now, focus only on product details
info = {'productCode':0,'title':'', 'gender':'', 'listPrice':'', 'productDescriptionRomance':'', 'productDescriptionTech':'', 'productDescriptionFit':'', 'colorsList':None, 'sizesMap':None}
def loadInfo(d):
    global context
    for k, v in d.items():
        if k in info:
            if k == 'listPrice':
                info[k] = str(v['formatted'])
                continue
            if isinstance(v, dict): info[k] = list(v.keys())
            else: info[k] = v

        if isinstance(v, dict):
            loadInfo(v)
loadInfo(descriptionDict)

def contextualize(info): 
    if info['colorsList'] != None:
        colorsList = []
        for element in info['colorsList']:
            for color in element['colors']: 
                if 'name' in color: colorsList.append(color['name'])
                if 'color' in color: colorsList.append(color['color'])
        info['colorsList'] = colorsList
    context = ''
    context += str(info['productCode']) + ' is ' + str(info['title']) + '\n'
    context += str(info['productCode']) + ' is for ' + str(info['gender']) + '\n'
    context += str(info['productCode']) + ' costs ' + str(info['listPrice']) + '\n'
    context += 'For ' + str(info['productCode']) + ', ' + info['productDescriptionRomance'] + '\n'
    for description in info['productDescriptionTech']:
        context += str(info['productCode']) + ' : ' + description + '\n'
    for description in info['productDescriptionFit']:
        context += str(info['productCode']) + ' has ' + description + '\n'

    if info['colorsList'] != None:
        context += str(info['productCode']) + ' has color '
        for color in info['colorsList']:
            context += color + ', and '
    context += '\n'
    
    if info['sizesMap'] != None:
        context += info['productCode'] + ' has size '
        for size in info['sizesMap']:
            if size == None: continue
            context += size + ', and'
    return context

context = contextualize(info)
with open('context.txt', 'w') as file:
    file.write(context)
    file.write('\n\n')
file.close()

# %% [markdown]
# ### 4. Try a BERT model as baseline

# %%
from transformers import BertForQuestionAnswering
from transformers import pipeline
from transformers import AutoTokenizer
model = BertForQuestionAnswering.from_pretrained('deepset/bert-base-cased-squad2')
tokenizer = AutoTokenizer.from_pretrained('deepset/bert-base-cased-squad2')
nlp = pipeline('question-answering', model=model, tokenizer=tokenizer)

# %%
questions = [
    "what is this product",
    "what is this product made of",
    "Is this product a dress or a jacket",
    "what is the title of this product",
    "what is the price for this product",
    "is this product for man or women",
    "is this product for summer or winter"
]
for question in questions:

    answer = nlp({
        'question':question,
        'context': context
    })
    print(question + " : " + str(answer))
# Out:
# what is this product : {'score': 0.07867526262998581, 'start': 323, 'end': 362, 'answer': 'this sweet style is soft, snug and chic'}
# what is this product made of : {'score': 0.04123115539550781, 'start': 323, 'end': 362, 'answer': 'this sweet style is soft, snug and chic'}
# Is this product a dress or a jacket : {'score': 0.31645408272743225, 'start': 165, 'end': 175, 'answer': 'a cardigan'}
# what is the title of this product : {'score': 0.04958398640155792, 'start': 127, 'end': 132, 'answer': 'BR789'}
# what is the price for this product : {'score': 0.5577917695045471, 'start': 115, 'end': 122, 'answer': '$178.00'}
# is this product for man or women : {'score': 0.13194237649440765, 'start': 78, 'end': 83, 'answer': 'women'}
# is this product for summer or winter : {'score': 0.0428488552570343, 'start': 208, 'end': 248, 'answer': 'days that feel somewhere between seasons'}

# %% [markdown]
# ### 5. Try Langchain

# %%
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.vectorstores import FAISS
from langchain.embeddings import OpenAIEmbeddings
from langchain.llms import OpenAI
import os
os.environ['OPENAI_API_KEY'] = "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"

loader = TextLoader('context.txt')
documents = loader.load()

# %%
textSplitter = RecursiveCharacterTextSplitter(chunk_size = 200, chunk_overlap = 20)
texts = textSplitter.split_documents(documents)
embeddings = OpenAIEmbeddings()
db = FAISS.from_documents(texts, embeddings)
retriever = db.as_retriever()

# %%
docs = retriever.get_relevant_documents("How much is this lady jacket?")
print("\n\n".join([x.page_content[:200] for x in docs[:2]]))
# Out:
# BR789 is J.Crew: Odette sweater lady jacket in cotton-blend boucl&eacute; for women
# BR789 is for women
# BR789 costs $178.00
#
# For BR789, Somewhere between a jacket and a cardigan, this easy layer is perfect for days that feel somewhere between seasons. Featuring a crochet trim, gold button details and hook-and-eye closures,

# %% [markdown]
# ### 6. Crawl the webpage

# %%
visited = set()
pdps = set()
def crawl_site(url):
    # set up a set to store visited URLs
    
    
    # add the starting URL to the list of URLs to visit
    urls_to_visit = [url]

    while urls_to_visit:
        # get the next URL to visit
        url = urls_to_visit.pop(0)

        # if the URL has already been visited, skip it
        if url in visited:
            continue

        # make a request to the URL
        print(url)
        try:
            response = requests.get(url)

            soup = BeautifulSoup(response.content, 'html.parser')


            allTags = soup.find_all('script')
            descriptionStr = None
            for tag in allTags:
                if tag.string and tag.string.strip():
                    descriptionStr = tag.string.strip()
            descriptionDict = None
            try:
                descriptionDict = json.loads(descriptionStr)
            except json.JSONDecodeError as e:
                continue
            if 'props' in descriptionDict:
                if 'initialState' in descriptionDict['props']:
                    if 'products' in descriptionDict['props']['initialState']:
                        if 'productsByProductCode' in descriptionDict['props']['initialState']['products']:
                            pdps.add(url)

            # add any new URLs on the page to the list of URLs to visit
            for link in soup.find_all('a'):
                href = link.get('href')
                if href == None:
                    continue
                href = 'https://www.jcrew.com'+href
                if href not in visited:
                    urls_to_visit.append(href)

            # mark the URL as visited
            visited.add(url)
        except requests.exceptions.RequestException as e:
            continue

crawl_site('https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?style-fit=mens-pants-skinny&intcmp=mheader_pants-fit-skinny')
# Out:
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?style-fit=mens-pants-skinny&intcmp=mheader_pants-fit-skinny
# https://www.jcrew.com/l/rewards?intcmp=seealloffersnav_1_signupfree
# https://www.jcrew.com/l/credit_card?intcmp=seealloffersnav_1_applytoday
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.com/s/rewards
# https://www.jcrew.com/
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.com/plp/womens/features/new-arrivals
# https://www.jcrew.com/plp/mens/features/new-arrivals
# https://www.jcrew.com/plp/girls/features/new-arrivals
# https://www.jcrew.com/plp/boys/features/new-arrivals
# https://www.jcrew.com/plp/womens/features/the-wedding-shop
# https://www.jcrew.com/plp/womens/features/the-linen-shop
# https://www.jcrew.com/plp/womens/features/the-work-remix
# https://www.jcrew.com/plp/womens/features/olympias-picks
# https://www.jcrew.com/plp/womens/features/resort-wear
# https://www.jcrew.com/plp/womens/features/straw-accessories
# https://www.jcrew.com/feature/creative-spirit-series-with-sz-blockprints-x-jcrew
# https://www.jcrew.com/plp/womens/features/the-mothers-day-shop
# https://www.jcrew.com/feature/womens/the-jcrew-icons
# https://www.jcrew.com/plp/mens/features/wallace-and-barnes
# https://www.jcrew.com/plp/mens/features/the-wedding-shop
# https://www.jcrew.com/plp/mens/features/tech-shop
# https://www.jcrew.com/feature/mens/the-jcrew-icons
# https://www.jcrew.com/plp/mens/categories/clothing/shirts?sub-categories=men-shirts-secretwash
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos
# https://www.jcrew.com/plp/mens/features/the-linen-shop
# https://www.jcrew.com/r/feature/mens/source-materials
# https://www.jcrew.com/womens
# https://www.jcrew.com/all/womens/?trending=bestSeller
# https://www.jcrew.com/all/womens/?trending=topRated
# https://www.jcrew.com/plp/womens/features/brands-we-love
# https://www.jcrew.com/shop/re-imagined/womens
# https://www.jcrew.com/all/womens
# https://www.jcrew.com/sale/women
# https://www.jcrew.com/all/womens/categories/clothing
# https://www.jcrew.com/plp/womens/categories/clothing/dresses-and-jumpsuits
# https://www.jcrew.com/plp/womens/categories/clothing/shirts-and-tops
# https://www.jcrew.com/plp/womens/categories/clothing/sweaters
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops
# https://www.jcrew.com/plp/womens/categories/clothing/blazers
# https://www.jcrew.com/plp/womens/categories/clothing/pants
# https://www.jcrew.com/plp/womens/categories/clothing/denim
# https://www.jcrew.com/plp/womens/categories/clothing/skirts
# https://www.jcrew.com/plp/womens/categories/clothing/shorts
# https://www.jcrew.com/plp/womens/categories/clothing/coats-and-jackets
# https://www.jcrew.com/plp/womens/categories/clothing/sweatshirts-and-sweatpants
# https://www.jcrew.com/plp/womens/categories/clothing/active
# https://www.jcrew.com/plp/womens/categories/clothing/pajamas-and-intimates
# https://www.jcrew.com/plp/womens/categories/clothing/suiting
# https://www.jcrew.com/plp/womens/categories/clothing/maternity
# https://www.jcrew.com/all/womens/categories/shoes
# https://www.jcrew.com/all/womens/categories/shoes?sub-categories=womens~categories~shoes~sandals
# https://www.jcrew.com/all/womens/categories/shoes?sub-categories=womens~categories~shoes~heels
# https://www.jcrew.com/all/womens/categories/shoes?sub-categories=womens~categories~shoes~flats
# https://www.jcrew.com/all/womens/categories/shoes?sub-categories=womens~categories~shoes~oxfords-and-loafers
# https://www.jcrew.com/all/womens/categories/shoes?sub-categories=womens~categories~shoes~sneakers
# https://www.jcrew.com/all/womens/categories/shoes?sub-categories=womens~categories~shoes~made-in-italy
# https://www.jcrew.com/all/womens/categories/shoes?sub-categories=womens~categories~shoes~birkenstocks
# https://www.jcrew.com/all/womens/categories/accessories
# https://www.jcrew.com/plp/womens/categories/accessories/jewelry
# https://www.jcrew.com/plp/womens/categories/accessories/bags
# https://www.jcrew.com/plp/womens/categories/accessories/belts
# https://www.jcrew.com/plp/womens/categories/accessories/hair
# https://www.jcrew.com/plp/womens/categories/accessories/scarves-hats
# https://www.jcrew.com/plp/womens/categories/accessories/scarves-and-wraps
# https://www.jcrew.com/plp/womens/categories/accessories/socks-and-tights
# https://www.jcrew.com/plp/womens/categories/accessories/sunglasses-and-chains
# https://www.jcrew.com/plp/womens/categories/accessories/home
# https://www.jcrew.com/mens
# https://www.jcrew.com/all/mens/?trending=bestSeller
# https://www.jcrew.com/all/mens/?trending=topRated
# https://www.jcrew.com/plp/mens/features/brands-we-love
# https://www.jcrew.com/shop/re-imagined/mens
# https://www.jcrew.com/all/mens
# https://www.jcrew.com/sale/men
# https://www.jcrew.com/all/mens/categories/clothing
# https://www.jcrew.com/plp/mens/categories/clothing/shorts
# https://www.jcrew.com/plp/mens/categories/clothing/shirts
# https://www.jcrew.com/plp/mens/categories/clothing/dress-shirts
# https://www.jcrew.com/plp/mens/categories/clothing/suits-and-tuxedos
# https://www.jcrew.com/plp/mens/categories/clothing/blazers
# https://www.jcrew.com/plp/mens/categories/clothing/denim
# https://www.jcrew.com/plp/mens/categories/clothing/polos
# https://www.jcrew.com/plp/mens/categories/clothing/t-shirts
# https://www.jcrew.com/plp/mens/categories/clothing/swim
# https://www.jcrew.com/plp/mens/categories/clothing/sweaters
# https://www.jcrew.com/plp/mens/categories/clothing/sweatshirts-and-sweatpants
# https://www.jcrew.com/plp/mens/categories/clothing/coats-and-jackets
# https://www.jcrew.com/plp/mens/categories/clothing/pajamas-and-loungewear
# https://www.jcrew.com/plp/mens/categories/clothing/underwear-and-boxers
# https://www.jcrew.com/all/mens/categories/shoes
# https://www.jcrew.com/all/mens/categories/shoes?sub-categories=mens~categories~shoes~exclusives
# https://www.jcrew.com/all/mens/categories/shoes?sub-categories=mens~categories~shoes~sneakers
# https://www.jcrew.com/all/mens/categories/shoes?sub-categories=mens~categories~shoes~dress-shoes
# https://www.jcrew.com/all/mens/categories/shoes?sub-categories=mens~categories~shoes~birkenstocks
# https://www.jcrew.com/all/mens/categories/shoes?sub-categories=mens~categories~shoes~new-balance
# https://www.jcrew.com/all/mens/categories/shoes?sub-categories=mens~categories~shoes~boots
# https://www.jcrew.com/all/mens/categories/accessories
# https://www.jcrew.com/plp/mens/categories/accessories/ties-and-pocket-squares
# https://www.jcrew.com/plp/mens/categories/accessories/socks
# https://www.jcrew.com/plp/mens/categories/accessories/belts
# https://www.jcrew.com/plp/mens/categories/accessories/hats
# https://www.jcrew.com/plp/mens/categories/accessories/bags-and-wallets
# https://www.jcrew.com/plp/mens/categories/accessories/sunglasses
# https://www.jcrew.com/plp/mens/categories/accessories/home
# https://www.jcrew.com/plp/mens/categories/accessories/watches-and-jewelry
# https://www.jcrew.com/all/girls/?trending=bestSeller
# https://www.jcrew.com/all/girls/?trending=topRated
# https://www.jcrew.com/plp/girls/features/brands-we-love
# https://www.jcrew.com/shop/re-imagined/girls
# https://www.jcrew.com/all/girls
# https://www.jcrew.com/sale/girls
# https://www.jcrew.com/all/girls/categories/clothing
# https://www.jcrew.com/plp/girls/categories/clothing/dresses-and-jumpsuits
# https://www.jcrew.com/plp/girls/categories/clothing/tops-and-tees
# https://www.jcrew.com/plp/girls/categories/clothing/shorts
# https://www.jcrew.com/plp/girls/categories/clothing/swim-and-rash-guards
# https://www.jcrew.com/plp/girls/categories/clothing/active
# https://www.jcrew.com/plp/girls/categories/clothing/leggings-and-pants
# https://www.jcrew.com/plp/girls/categories/clothing/pajamas-and-underwear
# https://www.jcrew.com/plp/girls/categories/clothing/sweatshirts-and-sweatpants
# https://www.jcrew.com/plp/girls/categories/clothing/sweaters
# https://www.jcrew.com/plp/girls/categories/clothing/denim
# https://www.jcrew.com/plp/girls/categories/clothing/coats-and-jackets
# https://www.jcrew.com/plp/girls/categories/clothing/baby
# https://www.jcrew.com/all/girls/categories/shoes
# https://www.jcrew.com/all/girls/categories/accessories
# https://www.jcrew.com/all/boys/?trending=bestSeller
# https://www.jcrew.com/all/boys/?trending=topRated
# https://www.jcrew.com/plp/boys/features/brands-we-love
# https://www.jcrew.com/shop/re-imagined/boys
# https://www.jcrew.com/all/boys
# https://www.jcrew.com/sale/boys
# https://www.jcrew.com/all/boys/categories/clothing
# https://www.jcrew.com/plp/boys/categories/clothing/t-shirts-and-polos
# https://www.jcrew.com/plp/boys/categories/clothing/shirts
# https://www.jcrew.com/plp/boys/categories/clothing/shorts
# https://www.jcrew.com/plp/boys/categories/clothing/swim-and-rash-guards
# https://www.jcrew.com/plp/boys/categories/clothing/active
# https://www.jcrew.com/plp/boys/categories/clothing/suiting
# https://www.jcrew.com/plp/boys/categories/clothing/chinos-pants
# https://www.jcrew.com/plp/boys/categories/clothing/pajamas
# https://www.jcrew.com/plp/boys/categories/clothing/sweatshirts-and-sweatpants
# https://www.jcrew.com/plp/boys/categories/clothing/denim
# https://www.jcrew.com/plp/boys/categories/clothing/sweaters
# https://www.jcrew.com/plp/boys/categories/clothing/coats-and-jackets
# https://www.jcrew.com/plp/boys/categories/clothing/baby
# https://www.jcrew.com/all/boys/categories/shoes
# https://www.jcrew.com/all/boys/categories/accessories
# https://www.jcrew.com/kids
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?swim-item=Bikini%20Top
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?swim-item=Bikini%20Bottom
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?swim-item=One-Piece
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?swim-item=Rash%20guard
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?swim-item=Beach%20Cover-ups
# https://www.jcrew.com/feature/creative-spirit-series-with-dauphinette-x-jcrew
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?sub-categories=women-swimwear-ruched
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?l_pattern=root-stripes
# https://www.jcrew.com/feature/womens-swim-fit-guide
# https://www.jcrew.com/plp/mens/categories/clothing/swim?sub-categories=men-swim-6-inch-swim-trunk
# https://www.jcrew.com/plp/mens/categories/clothing/swim?sub-categories=men-swim-7-inch-pool-short
# https://www.jcrew.com/plp/mens/categories/clothing/swim?sub-categories=men-swim-8-inch-swim-trunk
# https://www.jcrew.com/plp/girls/categories/clothing/swim-and-rash-guards?sub-categories=girls-swim-one-pieces
# https://www.jcrew.com/plp/girls/categories/clothing/swim-and-rash-guards?sub-categories=girls-swim-two-pieces
# https://www.jcrew.com/plp/girls/categories/clothing/swim-and-rash-guards?sub-categories=girls-swim-rash-guards
# https://www.jcrew.com/plp/girls/categories/clothing/swim-and-rash-guards?sub-categories=girls-swim-beach-coverups
# https://www.jcrew.com/plp/boys/categories/clothing/swim-and-rash-guards?sub-categories=boy-trunks
# https://www.jcrew.com/plp/boys/categories/clothing/swim-and-rash-guards?sub-categories=boy-rash-guards
# https://www.jcrew.com/plp/womens/features/the-cashmere-shop
# https://www.jcrew.com/plp/mens/features/the-cashmere-shop
# https://www.jcrew.com/plp/girls/features/the-cashmere-shop
# https://www.jcrew.com/plp/boys/features/the-cashmere-shop
# https://www.jcrew.com/plp/baby/features/the-cashmere-shop
# https://www.jcrew.com/plp/home
# https://www.jcrew.com/plp/home/features/new-arrivals
# https://www.jcrew.com/plp/home/features/brands-we-love
# https://www.jcrew.com/sale/home
# https://www.jcrew.com/plp/home/categories/dining-and-entertainment
# https://www.jcrew.com/plp/home/categories/bedding-and-bath
# https://www.jcrew.com/plp/home/categories/candles-and-fragrance
# https://www.jcrew.com/plp/home/categories/decor-and-gifts
# https://www.jcrew.com/plp/home/categories/beauty-and-wellness
# https://www.jcrew.com/plp/home/categories/home-office-and-tech
# https://www.jcrew.com/plp/home/categories/travel-and-gear
# https://www.jcrew.com/plp/home/categories/pets
# https://www.jcrew.com/r/feature/pages/the-jcrew-collective
# https://www.jcrew.com/feature/jcrew-40th-anniversary
# https://www.jcrew.com/plp/womens/features/embellishments
# https://www.jcrew.com/feature/local-time-with-leigh-altshuler
# https://www.jcrew.com/shop/mini-me-shop
# https://www.jcrew.com/plp/mens/features/alden-x-jcrew
# https://www.jcrew.com/feature/barbour_x_jcrew_with_eric_ripert
# https://www.jcrew.com/sale
# https://www.jcrew.com/shop/swim-and-more-sale/womens
# https://www.jcrew.com/sale/women?Nsrt=Newest
# https://www.jcrew.com/sale/women?price=(0..50)
# https://www.jcrew.com/sale/women?discount=60to70Off%2Cabove70Off
# https://www.jcrew.com/sale/girls?Nsrt=Newest
# https://www.jcrew.com/sale/girls?price=(0..50)
# https://www.jcrew.com/sale/girls?discount=60to70Off%2Cabove70Off
# https://www.jcrew.com/sale/men?Nsrt=Newest
# https://www.jcrew.com/sale/men?price=(0..50)
# https://www.jcrew.com/sale/men?discount=60to70Off%2Cabove70Off
# https://www.jcrew.com/sale/boys?Nsrt=Newest
# https://www.jcrew.com/sale/boys?price=(0..50)
# https://www.jcrew.com/sale/boys?discount=60to70Off%2Cabove70Off
# https://www.jcrew.com/feature/resale
# https://www.jcrew.com/checkout/cart?alertType=minicart_abandon
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.comjavascript:for (let i=0;i<=5;i++) {setTimeout(function(){document.getElementsByClassName('denimImageLayer1')[i].style.display = 'inline-block';document.getElementsByClassName('denimImageLayer2')[i].style.display = 'none';document.getElementsByClassName('fabricTextLayer')[i*2].style.opacity = 0;document.getElementsByClassName('fabricTextLayer')[(i*2)+1].style.opacity = 0;},i*50);setTimeout(function(){document.getElementsByClassName('denimImageLayer1')[i].classList.add('opacity-100');document.getElementsByClassName('denimImageLayer2')[i].classList.remove('opacity-100');document.getElementsByClassName('fabricTextLayer')[i].classList.add('no-click');document.getElementsByClassName('fabricTextLayer')[i*2].classList.add('no-click');}, i*70);}document.getElementsByClassName('headerToggle1')[0].classList.add('buttonOn');document.getElementsByClassName('headerToggle2')[0].classList.remove('buttonOn');
# https://www.jcrew.comjavascript:for (let i=0;i<=5;i++) {setTimeout(function(){document.getElementsByClassName('denimImageLayer1')[i].style.display = 'none';document.getElementsByClassName('denimImageLayer2')[i].style.display = 'inline-block';document.getElementsByClassName('denimImageLayer2')[i].style.position = 'relative';document.getElementsByClassName('fabricTextLayer')[i*2].style.opacity = 1;document.getElementsByClassName('fabricTextLayer')[(i*2)+1].style.opacity = 1;},i*50);setTimeout(function(){document.getElementsByClassName('denimImageLayer1')[i].classList.remove('opacity-100');document.getElementsByClassName('denimImageLayer2')[i].classList.add('opacity-100');document.getElementsByClassName('denimImageLayer2')[i].classList.remove('no-click');document.getElementsByClassName('fabricTextLayer')[i].classList.remove('no-click');document.getElementsByClassName('fabricTextLayer')[i*2].classList.remove('no-click');}, i*70);}document.getElementsByClassName('headerToggle1')[0].classList.remove('buttonOn');document.getElementsByClassName('headerToggle2')[0].classList.add('buttonOn');
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?sub-categories=men-pants-chinos-stretch-chino&intcmp=mheader_pants-fabric-stretch-chino
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?style-fit=mens-pants-slim&intcmp=mheader_pants-fit-slim
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?sub-categories=men-pants-chinos-cotton-linen&intcmp=mheader_pants-fabric-cotton-linen
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?style-fit=mens-pants-straight&intcmp=mheader_pants-fit-straight
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?sub-categories=men-pants-chinos-chino&intcmp=mheader_pants-fabric-chino
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?style-fit=Athletic%20Tapered&intcmp=mheader_pants-fit-athletic_tapered
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?sub-categories=men-pants-chinos-tech&intcmp=mheader_pants-fabric-tech
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?style-fit=mens-pants-relaxed&intcmp=mheader_pants-fit-relaxed
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?sub-categories=men-pants-chinos-five-pocket-twill&intcmp=mheader_pants-fabric-five-pocket-twill
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?style-fit=Giant&intcmp=mheader_pants-fit-giant
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?sub-categories=men-pants-chinos-corduroy&intcmp=mheader_pants-fabric-corduroy
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&style-fit=mens-pants-skinny,mens-pants-slim
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&style-fit=mens-pants-skinny,mens-pants-straight
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&style-fit=mens-pants-relaxed,mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&style-fit=Athletic%20Tapered,mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&style-fit=Giant,mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?sub-categories=men-pants-chinos-stretch-chino&crawl=no&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=28%2F30&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=28%2F32&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=29%2F30&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=29%2F32&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=30%2F30&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=30%2F32&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=30%2F34&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=31%2F30&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=31%2F32&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=31%2F34&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=32%2F30&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=32%2F32&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=32%2F34&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=33%2F30&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=33%2F32&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=33%2F34&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=34%2F30&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=34%2F32&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=34%2F34&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=35%2F32&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=36%2F32&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&size=36%2F34&style-fit=mens-pants-skinny
# https://www.jcrew.com
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&l_color=root-black&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&l_color=root-gray&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&l_color=root-green&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&l_color=root-navy&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&l_color=root-neutral&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&discount=lessThan40Off&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&pmid=msg-30-off-full-price%2Cmsg-pam-promo%2Cmsg-30-off-sale~SHOPNOW&style-fit=mens-pants-skinny
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?crawl=no&style-fit=mens-pants-skinny&trending=topRated
# https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?clothing=Sustainable&crawl=no&style-fit=mens-pants-skinny
# https://www.jcrew.com/m/mens/categories/clothing/pants-and-chinos/skinny/250-skinny-fit-pant-in-stretch-chino/MP714?display=standard&fit=Skinny&color_name=khaki&colorProductCode=AB613
# https://www.jcrew.com/m/mens/categories/clothing/pants-and-chinos/skinny/250-skinny-fit-pant-in-stretch-chino/MP714?display=standard&fit=Skinny&color_name=river-brown&colorProductCode=AB613
# https://www.jcrew.com/m/mens/categories/clothing/pants-and-chinos/skinny/250-skinny-fit-pant-in-stretch-chino/MP714?display=standard&fit=Skinny&color_name=catskill-green&colorProductCode=AB613
# https://www.jcrew.com/m/mens/categories/clothing/pants-and-chinos/skinny/250-skinny-fit-pant-in-stretch-chino/MP714?display=standard&fit=Skinny&color_name=black&colorProductCode=AB613
# https://www.jcrew.com/m/mens/categories/clothing/pants-and-chinos/skinny/250-skinny-fit-pant-in-stretch-chino/MP714?display=standard&fit=Skinny&color_name=navy&colorProductCode=AB613
# https://www.jcrew.com/m/mens/categories/clothing/pants-and-chinos/skinny/250-skinny-fit-pant-in-stretch-chino/MP714?display=standard&fit=Skinny&color_name=weathered-chino&colorProductCode=AB613
# https://www.jcrew.com/m/mens/categories/clothing/pants-and-chinos/skinny/250-skinny-fit-pant-in-stretch-chino/MP714?display=standard&fit=Skinny&color_name=onyx-grey&colorProductCode=AB613
# https://www.jcrew.com/m/mens/categories/clothing/pants-and-chinos/skinny/250-skinny-fit-pant-in-stretch-chino/MP714?display=standard&fit=Skinny&color_name=mushroom&colorProductCode=AB613
# https://www.jcrew.com/sale/men?sub-categories=mens-sale-pants-and-chinos&intcmp=JCrew:Mens:pants_link_to_cat_sale
# https://www.jcrew.comhttps://twitter.com/jcrew_help
# https://www.jcrew.comtel:1 800 562 0258
# https://www.jcrew.commailto:help@jcrew.com
# https://www.jcrew.com/help/customer-service
# https://www.jcrew.com/help/order-status
# https://www.jcrew.com/help/returns-exchanges
# https://www.jcrew.com/help/shipping-handling
# https://www.jcrew.com/help/international-orders
# https://www.jcrew.com/afterpay-faq
# https://www.jcrew.com/help/contact-us
# https://www.jcrew.comhttps://stores.jcrew.com/search
# https://www.jcrew.com/s/store-services
# https://www.jcrew.com/s/style-on-demand
# https://www.jcrew.com/help/gift-card
# https://www.jcrew.com/r/size-charts
# https://www.jcrew.com/s/teacher-student-discount
# https://www.jcrew.com/s/military-medical-first-responder-discount
# https://www.jcrew.com/share
# https://www.jcrew.com/best-deals
# https://www.jcrew.com/favorites
# https://www.jcrew.com/s/aboutus
# https://www.jcrew.comhttps://jobs.jcrew.com
# https://www.jcrew.com/s/corporate-responsibility
# https://www.jcrew.com/s/CSR-california-transparency-act
# https://www.jcrew.comhttps://investors.jcrew.com
# https://www.jcrew.com/help/terms-of-use
# https://www.jcrew.com/help/privacy-policy
# https://www.jcrew.comhttps://jcrew.clarip.com/dsr/create?brand=jcrew&type=3
# https://www.jcrew.com/s/diversity-equity-inclusion
# https://www.jcrew.comhttp://instagram.com/jcrew
# https://www.jcrew.comhttps://www.facebook.com/jcrew
# https://www.jcrew.comhttps://twitter.com/jcrew
# https://www.jcrew.comhttps://www.linkedin.com/company/j-crew
# https://www.jcrew.comhttp://pinterest.com/jcrew/
# https://www.jcrew.comhttp://www.youtube.com/user/jcrewinsider
# https://www.jcrew.com/r/context-chooser
# https://www.jcrew.comhttps://www.madewell.com
# https://www.jcrew.comhttps://factory.jcrew.com
# https://www.jcrew.com/?register=true
# https://www.jcrew.com/s/credit-card
# https://www.jcrew.comhttps://d.comenity.net/jcrew/
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.com/checkout/cart?alertType=minicart_abandon
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.comjavascript:window.jcrew.fnShowRegisterModal()
# https://www.jcrew.comjavascript:window.jcrew.fnShowSigninModal()
# https://www.jcrew.comhttps://d.comenity.net/ac/jcrew/public/home?srcCode=jcapplication
# https://www.jcrew.com/r/feature/pages/july-tc
# https://www.jcrew.comhttps://d.comenity.net/ac/jcrew/public/home?srcCode=jcapplication
# https://www.jcrew.comhttps://twitter.com/jcrew_help
# https://www.jcrew.comtel:1 800 562 0258
# https://www.jcrew.comhttps://stores.jcrew.com/search
# https://www.jcrew.comhttps://jobs.jcrew.com
# https://www.jcrew.comhttps://investors.jcrew.com
# https://www.jcrew.comhttps://jcrew.clarip.com/dsr/create?brand=jcrew&type=3
# https://www.jcrew.comhttp://instagram.com/jcrew
# https://www.jcrew.comhttps://www.facebook.com/jcrew
# https://www.jcrew.comhttps://twitter.com/jcrew
# https://www.jcrew.comhttps://www.linkedin.com/company/j-crew
# https://www.jcrew.comhttp://pinterest.com/jcrew/
# https://www.jcrew.comhttp://www.youtube.com/user/jcrewinsider
# https://www.jcrew.comhttps://www.madewell.com
# https://www.jcrew.comhttps://factory.jcrew.com
# https://www.jcrew.comhttps://d.comenity.net/jcrew/
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.com/checkout/cart?alertType=minicart_abandon
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.comhttps://d.comenity.net/ac/jcrew/public/home?srcCode=jcapplication
# https://www.jcrew.comhttps://d.comenity.net/ac/jcrew/public/home?srcCode=jcapplication
# https://www.jcrew.comhttps://d.comenity.net/ac/jcrew/public/home?srcCode=jcapplication
# https://www.jcrew.comhttps://d.comenity.net/ac/jcrew/public/home?srcCode=jcapplication
# https://www.jcrew.comhttps://d.comenity.net/jcrew/pub/requestCca/requestCca.xhtml
# https://www.jcrew.comhttps://twitter.com/jcrew_help
# https://www.jcrew.comtel:1 800 562 0258
# https://www.jcrew.comhttps://stores.jcrew.com/search
# https://www.jcrew.comhttps://jobs.jcrew.com
# https://www.jcrew.comhttps://investors.jcrew.com
# https://www.jcrew.comhttps://jcrew.clarip.com/dsr/create?brand=jcrew&type=3
# https://www.jcrew.comhttp://instagram.com/jcrew
# https://www.jcrew.comhttps://www.facebook.com/jcrew
# https://www.jcrew.comhttps://twitter.com/jcrew
# https://www.jcrew.comhttps://www.linkedin.com/company/j-crew
# https://www.jcrew.comhttp://pinterest.com/jcrew/
# https://www.jcrew.comhttp://www.youtube.com/user/jcrewinsider
# https://www.jcrew.comhttps://www.madewell.com
# https://www.jcrew.comhttps://factory.jcrew.com
# https://www.jcrew.comhttps://d.comenity.net/jcrew/
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.com/checkout/cart?alertType=minicart_abandon
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.comjavascript:window.jcrew.fnShowRegisterModal()
# https://www.jcrew.comjavascript:window.jcrew.fnShowSigninModal()
# https://www.jcrew.comhttps://d.comenity.net/ac/jcrew/public/home?srcCode=jcapplication
# https://www.jcrew.comhttps://d.comenity.net/ac/jcrew/public/home?srcCode=jcapplication
# https://www.jcrew.comhttps://twitter.com/jcrew_help
# https://www.jcrew.comtel:1 800 562 0258
# https://www.jcrew.comhttps://stores.jcrew.com/search
# https://www.jcrew.comhttps://jobs.jcrew.com
# https://www.jcrew.comhttps://investors.jcrew.com
# https://www.jcrew.comhttps://jcrew.clarip.com/dsr/create?brand=jcrew&type=3
# https://www.jcrew.comhttp://instagram.com/jcrew
# https://www.jcrew.comhttps://www.facebook.com/jcrew
# https://www.jcrew.comhttps://twitter.com/jcrew
# https://www.jcrew.comhttps://www.linkedin.com/company/j-crew
# https://www.jcrew.comhttp://pinterest.com/jcrew/
# https://www.jcrew.comhttp://www.youtube.com/user/jcrewinsider
# https://www.jcrew.comhttps://www.madewell.com
# https://www.jcrew.comhttps://factory.jcrew.com
# https://www.jcrew.comhttps://d.comenity.net/jcrew/
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.com/checkout/cart?alertType=minicart_abandon
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.comhttps://twitter.com/jcrew_help
# https://www.jcrew.comtel:1 800 562 0258
# https://www.jcrew.comhttps://stores.jcrew.com/search
# https://www.jcrew.comhttps://jobs.jcrew.com
# https://www.jcrew.comhttps://investors.jcrew.com
# https://www.jcrew.comhttps://jcrew.clarip.com/dsr/create?brand=jcrew&type=3
# https://www.jcrew.comhttp://instagram.com/jcrew
# https://www.jcrew.comhttps://www.facebook.com/jcrew
# https://www.jcrew.comhttps://twitter.com/jcrew
# https://www.jcrew.comhttps://www.linkedin.com/company/j-crew
# https://www.jcrew.comhttp://pinterest.com/jcrew/
# https://www.jcrew.comhttp://www.youtube.com/user/jcrewinsider
# https://www.jcrew.comhttps://www.madewell.com
# https://www.jcrew.comhttps://factory.jcrew.com
# https://www.jcrew.comhttps://d.comenity.net/jcrew/
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.com/checkout/cart?alertType=minicart_abandon
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.com/plp/womens/features/new-arrivals?Npge=1&Nrpp=120
# https://www.jcrew.com/plp/womens/features/new-arrivals?sub-categories=women-na-sweaters
# https://www.jcrew.com/plp/womens/features/new-arrivals?sub-categories=women-na-shirtsAndTops
# https://www.jcrew.com/plp/womens/features/new-arrivals?sub-categories=women-na-blazers
# https://www.jcrew.com/plp/womens/features/new-arrivals?sub-categories=women-na-pants
# https://www.jcrew.com/plp/womens/features/new-arrivals?sub-categories=women-na-tshirtsAndTankTops
# https://www.jcrew.com/plp/womens/features/new-arrivals?sub-categories=women-na-dressesAndJumpsuits
# https://www.jcrew.com/plp/womens/features/new-arrivals?sub-categories=women-na-swimwear
# https://www.jcrew.com/plp/womens/features/new-arrivals?sub-categories=women-na-denim
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&fit=Classic
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&fit=Petite
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&fit=Tall
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&fit=Long%20torso
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&fit=Full%2FQueen
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&fit=Queen
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&fit=King
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=000
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=00
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=0
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=2
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=4
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=5
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=6
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=7
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=8
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=10
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=12
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=14
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=16
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=18
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=20
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=22
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=24
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=XXX-SMALL
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=XX-SMALL
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=X-SMALL
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=SMALL
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=LARGE
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=X-LARGE
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=XX-LARGE
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=2X
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=3X
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=X-SMALL%2FSMALL
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=SMALL-MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=MEDIUM%20LARGE
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=MEDIUM-LARGE
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=23
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=24G
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=25
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=26
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=27
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=28
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=29
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=30
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=31
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=32
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=33
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=34
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=35
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=36
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=37
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=38
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=39
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=40
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=41
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=4%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=4H%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=5%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=5H%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=6%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=6H%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=7%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=7H%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=8%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=8H%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=9%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=9H%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=10%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=10H%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=11%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=12%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=32A
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=32B
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=32C
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=32D
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=34A
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=34B
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=34C
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=34D
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=36A
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=36B
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=36C
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=36D
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=38C
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=38D
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=40D
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=42D
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=ONE%20SIZE
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2000
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%200
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%202
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%204
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%206
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%208
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2010
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2012
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%20XX%20SMALL
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%20X%20SMALL
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%20SMALL
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%20LARGE
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2023
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2024
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2025
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2026
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2027
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2028
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2029
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2030
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2031
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=PETITE%2032
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%20SIZE%200
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%202
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%204
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%206
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%208
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2010
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2012
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2014
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2016
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2018
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2020
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%20X-SMALL
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%20SMALL
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%20MEDIUM
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%20LARGE
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%20X-LARGE
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2025
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2026
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2027
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2028
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2029
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2030
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2031
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=TALL%2032
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=FULQ
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&size=KING
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-black
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-blue
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-brown
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-gold
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-gray
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-green
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-multicolor
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-navy
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-neutral
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-orange
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-pink
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-purple
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-red
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-silver
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-white
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_color=root-yellow
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_pattern=root-brocade
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_pattern=root-dots
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_pattern=root-floral
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_pattern=root-gingham
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_pattern=root-graphic
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_pattern=root-jacquard
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_pattern=root-marled
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_pattern=root-paisley
# https://www.jcrew.com/plp/womens/features/new-arrivals?l_pattern=root-stripes
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&discount=above70Off
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&discount=60to70Off
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&discount=40to60Off
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&discount=lessThan40Off
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&pmid=msg-30-off-full-price%2Cmsg-pam-promo%2Cmsg-30-off-sale~SHOPNOW
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&trending=bestSeller
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&trending=topRated
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&trending=newLast2Weeks
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&trending=newLast4Weeks
# https://www.jcrew.com/plp/womens/features/new-arrivals?crawl=no&trending=monogrammable
# https://www.jcrew.com/plp/womens/features/new-arrivals?brand=BIRKENSTOCK
# https://www.jcrew.com/plp/womens/features/new-arrivals?brand=DAUPHINETTE
# https://www.jcrew.com/plp/womens/features/new-arrivals?brand=LIBERTY
# https://www.jcrew.com/plp/womens/features/new-arrivals?brand=New%20Balance
# https://www.jcrew.com/plp/womens/features/new-arrivals?brand=RECESS
# https://www.jcrew.com/plp/womens/features/new-arrivals?brand=REEBOK
# https://www.jcrew.com/plp/womens/features/new-arrivals?brand=SZ%20BLOCKPRINTS
# https://www.jcrew.com/plp/womens/features/new-arrivals?brand=TRETORN
# https://www.jcrew.com/plp/womens/features/new-arrivals?clothing=Sustainable
# https://www.jcrew.com/plp/womens/features/new-arrivals?clothing=Fair%20Trade
# https://www.jcrew.com/plp/womens/features/new-arrivals?clothing=Organic
# https://www.jcrew.com/plp/womens/features/new-arrivals?clothing=Recycled
# https://www.jcrew.com/p/womens/categories/clothing/blazers/lady-jacket/odette-sweater-lady-jacket-in-cotton-blend-boucleacute/BR789?display=standard&fit=Classic&color_name=mediterranean-navy&colorProductCode=BR789
# https://www.jcrew.com/m/womens/categories/shoes/flats/hazel-strappy-sandals-in-leather/MP099?display=standard&fit=Classic&color_name=burnt-caramel&colorProductCode=BR616
# https://www.jcrew.com/p/womens/categories/clothing/dresses-and-jumpsuits/maxine-v-neck-shift-dress-in-linen/BR470?display=standard&fit=Classic&color_name=brilliant-kelly&colorProductCode=BR470
# https://www.jcrew.com/p/womens/categories/clothing/sweaters/pullovers/cropped-crochet-tank-top-in-silk-cotton-blend/BO171?display=standard&fit=Classic&color_name=warm-ivory&colorProductCode=BO171
# https://www.jcrew.com/p/womens/categories/clothing/dresses-and-jumpsuits/squareneck-mini-sweater-dress/BR343?display=standard&fit=Classic&color_name=bright-patina&colorProductCode=BR343
# https://www.jcrew.com/p/womens/categories/clothing/dresses-and-jumpsuits/relaxed-fit-short-sleeve-baird-mcnutt-irish-linen-shirtdress/AY623?display=standard&fit=Classic&color_name=navy&colorProductCode=AY623
# https://www.jcrew.com/r/shop-the-look?externalProductCodes=BO171-SR1435:BP499-NA6445:BP329-NA6095:H8908-BR6404:BG613-NA6167:BO299-YL5433:BG933-BL8133:BI521-NA5810:AZ717-EE0543:AK085-EB4815&intcmp=w_na_look1
# https://www.jcrew.com/r/shop-the-look?externalProductCodes=BO171-SR1435:BP499-NA6445:BP329-NA6095:H8908-BR6404:BG613-NA6167:BO299-YL5433&intcmp=w_na_look2
# https://www.jcrew.com/p/womens/categories/accessories/scarves-hats/hats/open-weave-packable-straw-hat/BH859?display=standard&fit=Classic&color_name=natural-straw&colorProductCode=BH859
# https://www.jcrew.com/p/womens/categories/clothing/shirts-and-tops/button-up-bow-top-in-cotton-poplin-eyelet/BP771?display=standard&fit=Classic&color_name=navy&colorProductCode=BP771
# ...
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?crawl=no&trending=newLast4Weeks
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?crawl=no&trending=monogrammable
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?brand=DAUPHINETTE
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?brand=LEMLEM
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?brand=MINNOW%20SWIM
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?brand=ONIA
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?brand=OOKIOH
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?brand=SZ%20BLOCKPRINTS
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?clothing=Sustainable
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?clothing=Fair%20Trade
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?clothing=Organic
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?clothing=Recycled
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-cutout-one-piece-swimsuit-in-green-paisley/BP262?display=standard&fit=Classic&color_name=green&colorProductCode=BP262
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-cutout-one-piece-swimsuit-in-green-paisley/BP262?display=standard&fit=Classic&color_name=green&colorProductCode=BP262
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-squareneck-bikini-top-in-green-paisley/BP255?display=standard&fit=Classic&color_name=green&colorProductCode=BP255
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-squareneck-bikini-top-in-green-paisley/BP255?display=standard&fit=Classic&color_name=green&colorProductCode=BP255
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-high-rise-full-coverage-bikini-bottom-in-green-paisley/BP256?display=standard&fit=Classic&color_name=green&colorProductCode=BP256
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-high-rise-full-coverage-bikini-bottom-in-green-paisley/BP256?display=standard&fit=Classic&color_name=green&colorProductCode=BP256
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-plunge-one-piece-swimsuit-in-green-paisley/BP257?display=standard&fit=Classic&color_name=green&colorProductCode=BP257
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-plunge-one-piece-swimsuit-in-green-paisley/BP257?display=standard&fit=Classic&color_name=green&colorProductCode=BP257
# https://www.jcrew.com/p/womens/categories/clothing/dresses-and-jumpsuits/bow-back-tiered-maxi-dress-in-soft-gauze/BP204?display=standard&fit=Classic&color_name=bright-kiwi&colorProductCode=BP204
# https://www.jcrew.com/p/womens/categories/clothing/dresses-and-jumpsuits/bow-back-tiered-maxi-dress-in-soft-gauze/BP204?display=standard&fit=Classic&color_name=bright-kiwi&colorProductCode=BP204
# https://www.jcrew.com/p/womens/categories/clothing/button-front-tiered-cover-up-dress-in-cotton-voile/BQ963?display=standard&fit=Classic&color_name=dark-evening&colorProductCode=BQ963
# https://www.jcrew.com/p/womens/categories/clothing/button-front-tiered-cover-up-dress-in-cotton-voile/BQ963?display=standard&fit=Classic&color_name=dark-evening&colorProductCode=BQ963
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-ruched-one-shoulder-one-piece-swimsuit-in-nila-print/BP252?display=standard&fit=Classic&color_name=blue&colorProductCode=BP252
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-ruched-one-shoulder-one-piece-swimsuit-in-nila-print/BP252?display=standard&fit=Classic&color_name=blue&colorProductCode=BP252
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-underwire-bikini-top-in-nila-print/BP259?display=standard&fit=Classic&color_name=blue&colorProductCode=BP259
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-underwire-bikini-top-in-nila-print/BP259?display=standard&fit=Classic&color_name=blue&colorProductCode=BP259
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-classic-full-coverage-bikini-bottom-in-nila-print/BP261?display=standard&fit=Classic&color_name=blue&colorProductCode=BP261
# https://www.jcrew.com/p/womens/categories/clothing/swimwear/sz-blockprintstrade-x-jcrew-classic-full-coverage-bikini-bottom-in-nila-print/BP261?display=standard&fit=Classic&color_name=blue&colorProductCode=BP261
# https://www.jcrew.com/r/shop-the-look?externalProductCodes=BP190-PT2975:BN889-BL6861:BO959-EC7253&intcmp=w_swim_look2a
# https://www.jcrew.com/r/shop-the-look?externalProductCodes=BP189-PT2975:BO955-EC7253:BM642-WT0002&intcmp=w_weddingshop_look2b
# https://www.jcrew.com/r/shop-the-look?externalProductCodes=BP207-BK0001&intcmp=w_swim_look3
# https://www.jcrew.com/r/shop-the-look?externalProductCodes=BP177-PT3221:BP178-PT3221:BP172-PT3221:BP515-PT3221:BR366-EE4798&intcmp=w_swim_look4a
# https://www.jcrew.com/r/shop-the-look?externalProductCodes=BP172-PT3221:BP177-PT3221:BR366-EE4798&intcmp=w_swim_look4b
# https://www.jcrew.com/feature/creative-spirit-series-with-dauphinette-x-jcrew?intcmp=w_swim_dauphinette_feature
# https://www.jcrew.com/r/shop-the-look?externalProductCodes=BP236-YD3057&intcmp=w_swim_look5a
# https://www.jcrew.com/r/shop-the-look?externalProductCodes=BP233-YD3057:BP236-YD3057:K6518-EC7246&intcmp=w_swim_look5b
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?Npge=1
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?Npge=2
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?Npge=3
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?Npge=4
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?Npge=5
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?Npge=2
# https://www.jcrew.com/plp/womens/categories/clothing/swimwear?Npge=1&Nrpp=120
# https://www.jcrew.comhttps://twitter.com/jcrew_help
# https://www.jcrew.comtel:1 800 562 0258
# https://www.jcrew.comhttps://stores.jcrew.com/search
# https://www.jcrew.comhttps://jobs.jcrew.com
# https://www.jcrew.comhttps://investors.jcrew.com
# https://www.jcrew.comhttps://jcrew.clarip.com/dsr/create?brand=jcrew&type=3
# https://www.jcrew.comhttp://instagram.com/jcrew
# https://www.jcrew.comhttps://www.facebook.com/jcrew
# https://www.jcrew.comhttps://twitter.com/jcrew
# https://www.jcrew.comhttps://www.linkedin.com/company/j-crew
# https://www.jcrew.comhttp://pinterest.com/jcrew/
# https://www.jcrew.comhttp://www.youtube.com/user/jcrewinsider
# https://www.jcrew.comhttps://www.madewell.com
# https://www.jcrew.comhttps://factory.jcrew.com
# https://www.jcrew.comhttps://d.comenity.net/jcrew/
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.com/checkout/cart?alertType=minicart_abandon
# https://www.jcrew.com/checkout/cart
# https://www.jcrew.comhttps://d.comenity.net/jcrew/?intcmp=seealloffersnav_1_manageyourcard
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?sub-categories=tshirts-tank-tops-short-sleeve&intcmp=wheader_tees-shortsleeve
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?sub-categories=tshirts-tank-tops-tanks-and-camis&intcmp=wheader_tees-tanks
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?sub-categories=tshirts-tank-tops-tops&intcmp=wheader_tees-dressedup
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?sub-categories=tshirts-tank-tops-long-sleeve&intcmp=wheader_tees-longsleeve
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?sub-categories=tshirts-tank-tops-graphic-tees&intcmp=wheader_tees-graphic-tees
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?Npge=1&Nrpp=120
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?sub-categories=tshirts-tank-tops-long-sleeve
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?sub-categories=tshirts-tank-tops-short-sleeve
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?sub-categories=tshirts-tank-tops-graphic-tees
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?sub-categories=tshirts-tank-tops-tanks-and-camis
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?sub-categories=tshirts-tank-tops-turtlenecks
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?sub-categories=tshirts-tank-tops-tops
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?neckline=womens-knits-Halter
# https://www.jcrew.com/plp/womens/categories/clothing/t-shirts-and-tank-tops?neckline=womens-knits-Crewneck
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[57], line 56
#      53         except requests.exceptions.RequestException as e:
#      54             continue
# ---> 56 crawl_site('https://www.jcrew.com/plp/mens/categories/clothing/pants-and-chinos?style-fit=mens-pants-skinny&intcmp=mheader_pants-fit-skinny')
#
# Cell In[57], line 21, in crawl_site(url)
#      19 print(url)
#      20 try:
# ---> 21     response = requests.get(url)
#      23     soup = BeautifulSoup(response.content, 'html.parser')
#      26     allTags = soup.find_all('script')
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\site-packages\requests\sessions.py:587, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     582 send_kwargs = {
#     583     "timeout": timeout,
#     584     "allow_redirects": allow_redirects,
#     585 }
#     586 send_kwargs.update(settings)
# --> 587 resp = self.send(prep, **send_kwargs)
#     589 return resp
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\http\client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\http\client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\http\client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\ssl.py:1242, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238     if flags != 0:
#    1239         raise ValueError(
#    1240           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1241           self.__class__)
# -> 1242     return self.read(nbytes, buffer)
#    1243 else:
#    1244     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\Yubisoft\anaconda3\envs\nlp\lib\ssl.py:1100, in SSLSocket.read(self, len, buffer)
#    1098 try:
#    1099     if buffer is not None:
# -> 1100         return self._sslobj.read(len, buffer)
#    1101     else:
#    1102         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 7. Form a larger context

# %%
# use 20 urls from the crawler here for testing
pdps = ['https://www.jcrew.com/p/womens/categories/clothing/blazers/lady-jacket/odette-sweater-lady-jacket-in-cotton-blend-boucleacute/BR789?display=standard&fit=Classic&color_name=mediterranean-navy&colorProductCode=BR789',
'https://www.jcrew.com/m/womens/categories/shoes/flats/hazel-strappy-sandals-in-leather/MP099?display=standard&fit=Classic&color_name=burnt-caramel&colorProductCode=BR616',
'https://www.jcrew.com/p/womens/categories/clothing/dresses-and-jumpsuits/maxine-v-neck-shift-dress-in-linen/BR470?display=standard&fit=Classic&color_name=brilliant-kelly&colorProductCode=BR470',
'https://www.jcrew.com/p/womens/categories/clothing/sweaters/pullovers/cropped-crochet-tank-top-in-silk-cotton-blend/BO171?display=standard&fit=Classic&color_name=warm-ivory&colorProductCode=BO171',
'https://www.jcrew.com/p/womens/categories/clothing/dresses-and-jumpsuits/squareneck-mini-sweater-dress/BR343?display=standard&fit=Classic&color_name=bright-patina&colorProductCode=BR343',
'https://www.jcrew.com/p/womens/categories/clothing/dresses-and-jumpsuits/relaxed-fit-short-sleeve-baird-mcnutt-irish-linen-shirtdress/AY623?display=standard&fit=Classic&color_name=navy&colorProductCode=AY623',
'https://www.jcrew.com/r/shop-the-look?externalProductCodes=BO171-SR1435:BP499-NA6445:BP329-NA6095:H8908-BR6404:BG613-NA6167:BO299-YL5433:BG933-BL8133:BI521-NA5810:AZ717-EE0543:AK085-EB4815&intcmp=w_na_look1',
'https://www.jcrew.com/r/shop-the-look?externalProductCodes=BO171-SR1435:BP499-NA6445:BP329-NA6095:H8908-BR6404:BG613-NA6167:BO299-YL5433&intcmp=w_na_look2',
'https://www.jcrew.com/p/womens/categories/accessories/scarves-hats/hats/open-weave-packable-straw-hat/BH859?display=standard&fit=Classic&color_name=natural-straw&colorProductCode=BH859',
'https://www.jcrew.com/p/womens/categories/clothing/shirts-and-tops/button-up-bow-top-in-cotton-poplin-eyelet/BP771?display=standard&fit=Classic&color_name=navy&colorProductCode=BP771',
'https://www.jcrew.com/m/womens/categories/shoes/flats/menorca-toe-ring-slingback-sandals-in-leather/MP886?display=standard&fit=Classic&color_name=metallic-silver&colorProductCode=BR603',
'https://www.jcrew.com/p/mens/categories/shoes/dress-shoes/camden-loafers-in-leather/AV166?display=standard&fit=Classic&color_name=dress-brown&colorProductCode=AV166',
'https://www.jcrew.com/m/mens/categories/clothing/shirts/seersucker/short-sleeve-yarn-dyed-seersucker-shirt/MP604?display=standard&fit=Classic&color_name=seersucker-stripe-fade&colorProductCode=BE982',
'https://www.jcrew.com/p/mens/categories/clothing/t-shirts/performance/performance-t-shirt-with-coolmaxreg/BO520?display=standard&fit=Classic&color_name=soft-aqua&colorProductCode=BO520',
'https://www.jcrew.com/p/mens/categories/clothing/shirts/secret-wash/secret-wash-cotton-poplin-shirt/BJ706?display=standard&fit=Classic&color_name=henry-stripe-green-blue&colorProductCode=BJ706',
'https://www.jcrew.com/m/mens/categories/clothing/shorts/linen-and-seersucker/9quot-stretch-seersucker-short/MP949?display=standard&fit=9 Inch&color_name=sky-blue-white&colorProductCode=BO857',
'https://www.jcrew.com/p/mens/categories/clothing/shirts/shirt-jackets/wallace-amp-barnes-slub-poplin-military-shirt/BO866?display=standard&fit=Classic&color_name=classic-khaki&colorProductCode=BO866']

# %%
context = ''
for i in range(17):
    url = pdps[i]
    print(url)
    response = requests.get(url)
    html_content = response.text

    # Parse the HTML content using BeautifulSoup
    soup = BeautifulSoup(html_content, 'html.parser')


    allTags = soup.find_all('script')
    descriptionStr = None
    for tag in allTags:
        if tag.string and tag.string.strip():
            descriptionStr = tag.string.strip()
    descriptionDict = json.loads(descriptionStr)['props']['initialState']['products']['productsByProductCode']

    info = {'productCode':0,'title':'', 'gender':'', 'listPrice':'', 'productDescriptionRomance':'', 'productDescriptionTech':'', 'productDescriptionFit':'', 'colorsList':None, 'sizesMap':None}
    loadInfo(descriptionDict)
    print(info)
    currContext = contextualize(info)
    context += currContext + '\n\n\n'
# Out:
# https://www.jcrew.com/p/womens/categories/clothing/blazers/lady-jacket/odette-sweater-lady-jacket-in-cotton-blend-boucleacute/BR789?display=standard&fit=Classic&color_name=mediterranean-navy&colorProductCode=BR789
# {'productCode': 'BR789', 'title': 'J.Crew: Odette sweater lady jacket in cotton-blend boucl&eacute; for women', 'gender': 'women', 'listPrice': '$178.00', 'productDescriptionRomance': 'Somewhere between a jacket and a cardigan, this easy layer is perfect for days that feel somewhere between seasons. Featuring a crochet trim, gold button details and hook-and-eye closures, this sweet style is soft, snug and chic.', 'productDescriptionTech': ['70% cotton/30% polyamide.', 'Machine wash.', 'Import.'], 'productDescriptionFit': ['Cropped fit.', 'Hits slightly above hip.', 'Body length: 18 3/4".', 'Sleeve length: 30".'], 'colorsList': [{'price': {'amount': 178, 'formatted': '$178.00'}, 'colors': [{'productCode': 'BR789', 'code': 'YL5659', 'name': 'CRISP YELLOW'}, {'productCode': 'BR789', 'code': 'WT0002', 'name': 'WHITE'}, {'productCode': 'BR789', 'code': 'GR8019', 'name': 'KELLY GREEN'}, {'productCode': 'BR789', 'code': 'BL7505', 'name': 'MEDITERRANEAN NAVY'}]}], 'sizesMap': ['X-LARGE', 'X-SMALL', 'SMALL', 'XX-LARGE', 'MEDIUM', '2X', '3X', 'XX-SMALL', 'LARGE']}
# https://www.jcrew.com/m/womens/categories/shoes/flats/hazel-strappy-sandals-in-leather/MP099?display=standard&fit=Classic&color_name=burnt-caramel&colorProductCode=BR616
# {'productCode': 'BS356', 'title': 'J.Crew: Hazel strappy sandals in metallic leather for women', 'gender': 'women', 'listPrice': '$138.00', 'productDescriptionRomance': 'A new, cool take on our do-it-all sandal. . .With a polished ankle strap and knotted leather upper, this sleek pair is the perfect complement to your summer wardrobe.', 'productDescriptionTech': ['Leather upper.', 'Rubber outsole.', 'Import.', 'Select stores.'], 'productDescriptionFit': [], 'colorsList': [{'price': {'amount': 138, 'formatted': '$138.00'}, 'colors': [{'productCode': 'BS356', 'code': 'EE3794', 'name': 'PLATINO GOLD'}]}], 'sizesMap': ['11 MEDIUM', '9 MEDIUM', '10 MEDIUM', '6H MEDIUM', '7 MEDIUM', '5 MEDIUM', '9H MEDIUM', '8 MEDIUM', '5H MEDIUM', '12 MEDIUM', '8H MEDIUM', '6 MEDIUM', '7H MEDIUM', '10H MEDIUM']}
# https://www.jcrew.com/p/womens/categories/clothing/dresses-and-jumpsuits/maxine-v-neck-shift-dress-in-linen/BR470?display=standard&fit=Classic&color_name=brilliant-kelly&colorProductCode=BR470
# {'productCode': 'BR470', 'title': 'J.Crew: Maxine V-neck shift dress in linen for women', 'gender': 'women', 'listPrice': '$118.00', 'productDescriptionRomance': 'We&apos;re living in shift dresses right now because they&apos;re cute, easy and super-flattering. This one is all of the above and more, thanks to the double V-neck and mini length. Plus, this dress is made with a lightweight, super-breathable linen (aka our version of personal AC).', 'productDescriptionTech': ['100% linen.', 'Lined.', 'Machine wash.', 'Import.'], 'productDescriptionFit': ['Sheath silhouette.', 'Falls above knee, 38 1/2" from high point of shoulder (based on a size 6).'], 'colorsList': [{'price': {'amount': 118, 'formatted': '$118.00'}, 'colors': [{'productCode': 'BR470', 'code': 'PK5864', 'name': 'FUCHSIA'}, {'productCode': 'BR470', 'code': 'OR5174', 'name': 'SWEET TANGERINE'}, {'productCode': 'BR470', 'code': 'GR7805', 'name': 'BRILLIANT KELLY'}, {'productCode': 'BR470', 'code': 'BK0001', 'name': 'BLACK'}]}], 'sizesMap': ['TALL X-LARGE', 'TALL X-SMALL', 'TALL LARGE', 'TALL MEDIUM', 'TALL SMALL']}
# https://www.jcrew.com/p/womens/categories/clothing/sweaters/pullovers/cropped-crochet-tank-top-in-silk-cotton-blend/BO171?display=standard&fit=Classic&color_name=warm-ivory&colorProductCode=BO171
# {'productCode': 'BO171', 'title': 'J.Crew: Cropped crochet tank top in silk-cotton blend for women', 'gender': 'women', 'listPrice': '$148.00', 'productDescriptionRomance': 'That carefree spring feeling, in top form. This tank style features an intricate crochet design, a cropped length and a flattering square neckline, and is made with our smooth silk-cotton blend. By buying cotton products from J.Crew, you&apos;re supporting our investment in Better Cotton&apos;s mission to help cotton communities survive and thrive while protecting and restoring the environment. This product is sourced through a system of mass balance and therefore may not contain Better Cotton.', 'productDescriptionTech': ['55% silk/45% cotton.', 'Machine wash.', 'Import.', 'Select stores.'], 'productDescriptionFit': ['Fitted.', 'Body length: 17".', 'Hits slightly above hip.'], 'colorsList': [{'price': {'amount': 148, 'formatted': '$148.00'}, 'colors': [{'productCode': 'BO171', 'code': 'SR1435', 'name': 'WARM IVORY'}, {'productCode': 'BO171', 'code': 'OR0041', 'name': 'FIRE LILY'}, {'productCode': 'BO171', 'code': 'BK0001', 'name': 'BLACK'}]}], 'sizesMap': ['MEDIUM', 'SMALL', 'X-LARGE', 'XX-LARGE', '3X', '2X', 'LARGE', 'X-SMALL']}
# https://www.jcrew.com/p/womens/categories/clothing/dresses-and-jumpsuits/squareneck-mini-sweater-dress/BR343?display=standard&fit=Classic&color_name=bright-patina&colorProductCode=BR343
# {'productCode': 'BR343', 'title': 'J.Crew: Squareneck mini sweater-dress for women', 'gender': 'women', 'listPrice': '$128.00', 'productDescriptionRomance': 'Welcome to the era of the transitional sweater-dress: We&apos;re talking sophisticated knit pieces with endless styling potential. Like this chic style with a flattering squareneck and a mini length. . .By buying cotton products from J.Crew, you&apos;re supporting our investment in Better Cotton&apos;s mission to help cotton communities survive and thrive while protecting and restoring the environment. This product is sourced through a system of mass balance and therefore may not contain Better Cotton. Plus, it was crafted at a Fair Trade Certified&trade; factory that provides additional income and better conditions for the people who work there.', 'productDescriptionTech': ['53% cotton/47% viscose.', 'Machine wash.', 'Import.'], 'productDescriptionFit': ['A-line silhouette.', 'Falls above knee, 33 1/2" from high point of shoulder (based on a size 6).'], 'colorsList': [{'price': {'amount': 128, 'formatted': '$128.00'}, 'colors': [{'productCode': 'BR343', 'code': 'RD5285', 'name': 'BELVEDERE RED'}, {'productCode': 'BR343', 'code': 'GR7722', 'name': 'BRIGHT PATINA'}, {'productCode': 'BR343', 'code': 'BK0001', 'name': 'BLACK'}]}], 'sizesMap': ['SMALL', 'LARGE', 'XX-LARGE', '2X', 'MEDIUM', 'X-SMALL', 'X-LARGE', 'XX-SMALL', '3X']}
# https://www.jcrew.com/p/womens/categories/clothing/dresses-and-jumpsuits/relaxed-fit-short-sleeve-baird-mcnutt-irish-linen-shirtdress/AY623?display=standard&fit=Classic&color_name=navy&colorProductCode=AY623
# {'productCode': 'AY623', 'title': 'J.Crew: Relaxed-fit short-sleeve Baird McNutt Irish linen shirtdress for women', 'gender': 'women', 'listPrice': '$148.00', 'productDescriptionRomance': "The relaxed-fit shirt, all dressed up. Our design team spent months perfecting and wear-testing our relaxed fit to get it just right.  As our most oversized silhouette, it's meant to fit loose for an easy, laidback vibe. Whether you're wearing it unbuttoned over your favorite tee and jeans, as a swim cover-up or just with on it's own, our relaxed fit shirtdress makes any outfit feel that much cooler.This one is made with linen from Ireland's Baird McNutt mill (Irish linen is considered to be the world's finest, and Baird McNutt's the finest in Ireland) and it has an incredible softness, thanks to a weaving process that the mill has been perfecting since 1912.", 'productDescriptionTech': ['Linen.', 'Button closure.', 'Pockets.', 'Machine wash.', 'Import.', 'Select stores.'], 'productDescriptionFit': ['Nonwaisted.', 'Falls above knee, 40 1/4" from high point of shoulder (based on a size 6).'], 'colorsList': [{'price': {'amount': 148, 'formatted': '$148.00'}, 'colors': [{'productCode': 'AY623', 'code': 'PK5858', 'name': 'VIVID BEGONIA'}, {'productCode': 'AY623', 'code': 'NA6436', 'name': 'FLAX'}, {'productCode': 'AY623', 'code': 'GR1339', 'name': 'RICH OLIVE'}, {'productCode': 'AY623', 'code': 'BL8227', 'name': 'FRENCH BLUE'}, {'productCode': 'AY623', 'code': 'BL8133', 'name': 'NAVY'}]}], 'sizesMap': ['TALL X-SMALL', 'TALL LARGE', 'TALL SMALL', 'TALL X-LARGE', 'TALL MEDIUM']}
# https://www.jcrew.com/r/shop-the-look?externalProductCodes=BO171-SR1435:BP499-NA6445:BP329-NA6095:H8908-BR6404:BG613-NA6167:BO299-YL5433:BG933-BL8133:BI521-NA5810:AZ717-EE0543:AK085-EB4815&intcmp=w_na_look1
# {'productCode': 0, 'title': '', 'gender': '', 'listPrice': '', 'productDescriptionRomance': '', 'productDescriptionTech': '', 'productDescriptionFit': '', 'colorsList': None, 'sizesMap': None}
# https://www.jcrew.com/r/shop-the-look?externalProductCodes=BO171-SR1435:BP499-NA6445:BP329-NA6095:H8908-BR6404:BG613-NA6167:BO299-YL5433&intcmp=w_na_look2
# {'productCode': 0, 'title': '', 'gender': '', 'listPrice': '', 'productDescriptionRomance': '', 'productDescriptionTech': '', 'productDescriptionFit': '', 'colorsList': None, 'sizesMap': None}
# https://www.jcrew.com/p/womens/categories/accessories/scarves-hats/hats/open-weave-packable-straw-hat/BH859?display=standard&fit=Classic&color_name=natural-straw&colorProductCode=BH859
# {'productCode': 'BH859', 'title': 'J.Crew: Open-weave packable straw hat for women', 'gender': 'women', 'listPrice': '$69.50', 'productDescriptionRomance': 'A cool open weave makes this raffia style the perfect, breezy addition to every sunny day. Plus, it bounces back easily after a trip in your suitcase, carry-on or beach bag.', 'productDescriptionTech': ['Hand-crocheted raffia straw.', 'Import.', 'Select stores.'], 'productDescriptionFit': ['S/M, M/L.'], 'colorsList': [{'price': {'amount': 69.5, 'formatted': '$69.50'}, 'colors': [{'productCode': 'BH859', 'code': 'EB9318', 'name': 'NATURAL STRAW'}]}], 'sizesMap': ['MEDIUM LARGE', 'SMALL-MEDIUM']}
# https://www.jcrew.com/p/womens/categories/clothing/shirts-and-tops/button-up-bow-top-in-cotton-poplin-eyelet/BP771?display=standard&fit=Classic&color_name=navy&colorProductCode=BP771
# {'productCode': 'BP771', 'title': 'J.Crew: Button-up bow top in cotton poplin eyelet for women', 'gender': 'women', 'listPrice': '$158.00', 'productDescriptionRomance': 'A perfect lightweight option for when the weather starts to warm up, with breezy eyelet fabric, a bow detail at the collar and comfy, three-quarter sleeves. Plus, this shirt is crafted from our crisp cotton poplin, which is made with organic cotton that is grown without chemical fertilizers and pesticides from nongenetically modified seeds.', 'productDescriptionTech': ['100% cotton.', 'Machine wash.', 'Import.', 'Select stores.'], 'productDescriptionFit': ['Body length: 23 1/4".'], 'colorsList': [{'price': {'amount': 158, 'formatted': '$158.00'}, 'colors': [{'productCode': 'BP771', 'code': 'WT0002', 'name': 'WHITE'}, {'productCode': 'BP771', 'code': 'BL8133', 'name': 'NAVY'}]}], 'sizesMap': ['3X', 'MEDIUM', 'XX-SMALL', '2X', 'X-LARGE', 'SMALL', 'XX-LARGE', 'LARGE', 'X-SMALL']}
# https://www.jcrew.com/m/womens/categories/shoes/flats/menorca-toe-ring-slingback-sandals-in-leather/MP886?display=standard&fit=Classic&color_name=metallic-silver&colorProductCode=BR603
# {'productCode': 'BR603', 'title': 'J.Crew: Menorca toe-ring slingback sandals in leather for women', 'gender': 'women', 'listPrice': '$118.00', 'productDescriptionRomance': 'Introducing the Menorca sandal collection - a brand-new, more comfortable update to our customer-favorite Capri sandals. They&apos;re our newest and comfiest sandals yet - with a super-cushy, padded leather footbed. Our elevated take on the style, this slingback pair features a toe-ring silhouette in soft and supple leather.', 'productDescriptionTech': ['Leather upper and lining.', 'German outsole.', 'Import.', 'Select stores.'], 'productDescriptionFit': [], 'colorsList': [{'price': {'amount': 118, 'formatted': '$118.00'}, 'colors': [{'productCode': 'BR603', 'code': 'GY6589', 'name': 'METALLIC SILVER'}]}], 'sizesMap': ['7H MEDIUM', '5H MEDIUM', '8H MEDIUM', '9 MEDIUM', '6 MEDIUM', '9H MEDIUM', '10 MEDIUM', '7 MEDIUM', '6H MEDIUM', '11 MEDIUM', '8 MEDIUM', '10H MEDIUM', '12 MEDIUM', '5 MEDIUM']}
# https://www.jcrew.com/p/mens/categories/shoes/dress-shoes/camden-loafers-in-leather/AV166?display=standard&fit=Classic&color_name=dress-brown&colorProductCode=AV166
# {'productCode': 'AV166', 'title': 'J.Crew: Camden loafers in leather for men', 'gender': 'men', 'listPrice': '$158.00', 'productDescriptionRomance': 'These classic penny loafers are based on the original 1930s design that was popular with college students (it fit the two cents needed for a phone call). Our version is made with premium leather uppers and a smooth leather lining that will soften with every wear. With a durable rubber outsole, these loafers suitable for wearing every day.', 'productDescriptionTech': ['Leather upper and lining.', 'Rubber sole.', 'Import.', 'Select stores.'], 'productDescriptionFit': ['For the best fit, we recommend ordering a half size down from your usual size.'], 'colorsList': [{'price': {'amount': 158, 'formatted': '$158.00'}, 'colors': [{'productCode': 'AV166', 'code': 'RD5803', 'name': 'VINTAGE MERLOT'}, {'productCode': 'AV166', 'code': 'PP4555', 'name': 'DRESS BROWN'}, {'productCode': 'AV166', 'code': 'BK0001', 'name': 'BLACK'}]}], 'sizesMap': ['9H MEDIUM', '11H MEDIUM', '10 MEDIUM', '10H MEDIUM', '7 MEDIUM', '8 MEDIUM', '9 MEDIUM', '8H MEDIUM', '12 MEDIUM', '7H MEDIUM', '13 MEDIUM', '11 MEDIUM']}
# https://www.jcrew.com/m/mens/categories/clothing/shirts/seersucker/short-sleeve-yarn-dyed-seersucker-shirt/MP604?display=standard&fit=Classic&color_name=seersucker-stripe-fade&colorProductCode=BE982
# {'productCode': 'BE981', 'title': 'J.Crew: Short-sleeve seersucker shirt in print for men', 'gender': 'men', 'listPrice': '$79.50', 'productDescriptionRomance': 'Lightweight, comfortable and ideal for warm weather, our seersucker shirts are made with 100 percent cotton for breathability. Fun fact: Seersucker gets its name from the Persian phrase <i>shir-o-shakar</i> (&quot;milk and sugar&quot;), which describes its alternating smooth and textured stripes.', 'productDescriptionTech': ['Regular fit.', '100% cotton.', 'Machine wash.', 'Import.'], 'productDescriptionFit': ['For the taller guy, our tall fit is 2" longer in the body and sleeves.'], 'colorsList': [{'price': {'amount': 49.5, 'formatted': '$49.50'}, 'colors': [{'productCode': 'BE981', 'code': 'PP4491', 'name': 'ABSTRACT FLORAL LAKE BL'}]}], 'sizesMap': ['X LARGE-TALL', 'TALL SIZE MEDIUM', 'TALL LARGE']}
# https://www.jcrew.com/p/mens/categories/clothing/t-shirts/performance/performance-t-shirt-with-coolmaxreg/BO520?display=standard&fit=Classic&color_name=soft-aqua&colorProductCode=BO520
# {'productCode': 'BO520', 'title': 'J.Crew: Performance T-shirt with COOLMAX&reg; for men', 'gender': 'men', 'listPrice': '$49.50', 'productDescriptionRomance': 'We designed this tee in a soft, breathable cotton blend with COOLMAX technology that wicks away moisture and provides UPF 50+ sun protection so you&apos;re comfortable all day (and night). Plus, the built-in stretch moves with you whether you&apos;re around town, playing golf or just heading out for a neighborhood stroll.', 'productDescriptionTech': ['58% cotton/42% polyester.', 'Rib trim at neck.', 'Short sleeves.', 'Machine wash.', 'Import.', 'Select stores.'], 'productDescriptionFit': [], 'colorsList': [{'price': {'amount': 49.5, 'formatted': '$49.50'}, 'colors': [{'productCode': 'BO520', 'code': 'WT0002', 'name': 'WHITE'}, {'productCode': 'BO520', 'code': 'WQ9396', 'name': 'VINTAGE STRAW'}, {'productCode': 'BO520', 'code': 'WQ8812', 'name': 'SOFT AQUA'}, {'productCode': 'BO520', 'code': 'WQ8808', 'name': 'HTHR GREY'}, {'productCode': 'BO520', 'code': 'BL8133', 'name': 'NAVY'}, {'productCode': 'BO520', 'code': 'BK0001', 'name': 'BLACK'}]}], 'sizesMap': ['X-SMALL', 'LARGE', 'SMALL', 'X-LARGE', 'MEDIUM', 'XX-LARGE']}
# https://www.jcrew.com/p/mens/categories/clothing/shirts/secret-wash/secret-wash-cotton-poplin-shirt/BJ706?display=standard&fit=Classic&color_name=henry-stripe-green-blue&colorProductCode=BJ706
# {'productCode': 'BJ706', 'title': 'J.Crew: Secret Wash cotton poplin shirt for men', 'gender': 'men', 'listPrice': '$89.50', 'productDescriptionRomance': 'Re-introducing the pinnacle of shirt engineering. We&apos;ve revamped the super-versatile Secret Wash shirt with premium 100 percent cotton 100s two-ply yarns, plus an improved fit. &quot;100s&quot; refers to a finer yarn size, and &quot;two-ply&quot; means two yarns are twisted together to make a single thread. The result is smoother, stronger fabric. We also use our (proprietary) multistep wash process to achieve a soft, broken-in feel from day one. Long story short: The customer favorite since 2005 is now better than ever. By buying cotton products from J.Crew, you&apos;re supporting our investment in Better Cotton&apos;s mission to help cotton communities survive and thrive while protecting and restoring the environment. This product is sourced through a system of mass balance and therefore may not contain Better Cotton.', 'productDescriptionTech': ['100% cotton.'], 'productDescriptionFit': ['For the taller guy, our Tall fit is 2" longer in the body and sleeves.'], 'colorsList': [{'price': {'amount': 89.5, 'formatted': '$89.50'}, 'colors': [{'productCode': 'BJ706', 'code': 'YD3080', 'name': 'HENRY STRIPE GREEN BLUE'}, {'productCode': 'BJ706', 'code': 'YD3030', 'name': 'SURF BLUE END ON END'}, {'productCode': 'BJ706', 'code': 'YD3025', 'name': 'PALE BANANA END ON END'}, {'productCode': 'BJ706', 'code': 'YD0778', 'name': 'LAMPPOST GREEN EOE'}, {'productCode': 'BJ706', 'code': 'WW0699', 'name': 'WATERFALL'}, {'productCode': 'BJ706', 'code': 'WT0002', 'name': 'WHITE'}, {'productCode': 'BJ706', 'code': 'WO8694', 'name': 'MONTCLAIR NAVY'}, {'productCode': 'BJ706', 'code': 'PT4071', 'name': 'DOO DAD DOT IVORY NAVY'}, {'productCode': 'BJ706', 'code': 'PT4068', 'name': 'SPRING TOSS WHITE NAVY'}, {'productCode': 'BJ706', 'code': 'PT3263', 'name': 'SAKURA GARDEN NATURAL Y'}, {'productCode': 'BJ706', 'code': 'PT3196', 'name': 'BROOK GARDEN BLUE MULTI'}, {'productCode': 'BJ706', 'code': 'PT3195', 'name': 'TINY FLORAL NAVY MULTI'}, {'productCode': 'BJ706', 'code': 'PT1638', 'name': 'SPREDY BABY DOT NAVY MU'}, {'productCode': 'BJ706', 'code': 'BK0001', 'name': 'BLACK'}]}], 'sizesMap': ['TALL SIZE MEDIUM', 'TALL LARGE', 'X LARGE-TALL', 'XX-LARGE-TALL']}
# https://www.jcrew.com/m/mens/categories/clothing/shorts/linen-and-seersucker/9quot-stretch-seersucker-short/MP949?display=standard&fit=9 Inch&color_name=sky-blue-white&colorProductCode=BO857
# {'productCode': 'BO857', 'title': 'J.Crew: 9&quot; stretch seersucker short for men', 'gender': 'men', 'listPrice': '$89.50', 'productDescriptionRomance': 'We made these shorts in cool, crisp seersucker, a puckered warm-weather fabric, and added just enough stretch for comfort. Fun fact: Seersucker takes its name from the Persian phrase <i>shir-o-shakar</i> (&quot;milk and sugar&quot;), which describes its alternating smooth and textured stripes.', 'productDescriptionTech': ['100% linen.', 'Zip fly.', 'Machine wash.', 'Import.'], 'productDescriptionFit': ['Regular fit.', '9" inseam.'], 'colorsList': [{'price': {'amount': 59.5, 'formatted': '$59.50'}, 'colors': [{'productCode': 'BO857', 'code': 'WZ2839', 'name': 'PINK WHITE'}, {'productCode': 'BO857', 'code': 'WZ0070', 'name': 'SKY BLUE WHITE'}]}], 'sizesMap': ['28', '29', '30', '31', '32', '33', '34', '35', '36', '38']}
# https://www.jcrew.com/p/mens/categories/clothing/shirts/shirt-jackets/wallace-amp-barnes-slub-poplin-military-shirt/BO866?display=standard&fit=Classic&color_name=classic-khaki&colorProductCode=BO866
# {'productCode': 'BO866', 'title': 'J.Crew: Wallace &amp; Barnes slub poplin military shirt for men', 'gender': 'men', 'listPrice': '$118.00', 'productDescriptionRomance': 'Wallace &amp; Barnes is our exclusive collection of rugged essentials inspired by traditional workwear, military surplus, vintage uniforms and classic outdoor gear. In addition to its two buttoned pockets, this vintage-inspired shirt features a subtly textured slub poplin construction for a versatile, warm-weather mainstay that looks as good with denim as it does with chinos.', 'productDescriptionTech': ['100% cotton.', 'Machine wash.', 'Import.', 'Select stores.'], 'productDescriptionFit': ['Classic fit.'], 'colorsList': [{'price': {'amount': 118, 'formatted': '$118.00'}, 'colors': [{'productCode': 'BO866', 'code': 'YD3928', 'name': 'LIGHT NAVY'}, {'productCode': 'BO866', 'code': 'YD3927', 'name': 'CLASSIC KHAKI'}]}], 'sizesMap': ['X-LARGE', 'MEDIUM', 'X-SMALL', 'SMALL', 'XX-LARGE', 'LARGE']}

# %%
with open('largercontext.txt', 'w') as file:
    file.write(context)
    file.write('\n\n')
file.close()

# %% [markdown]
# ### 8. Ask LangChain Again

# %%
loader = TextLoader('largercontext.txt')
documents = loader.load()
textSplitter = RecursiveCharacterTextSplitter(chunk_size = 200, chunk_overlap = 20)
texts = textSplitter.split_documents(documents)
embeddings = OpenAIEmbeddings()
db = FAISS.from_documents(texts, embeddings)
retriever = db.as_retriever()
# Out:
# mini length. Plus, this dress is made with a lightweight, super-breathable linen (aka our version of personal AC).
#
# BR470 is J.Crew: Maxine V-neck shift dress in linen for women
# BR470 is for women
# BR470 costs $118.00

# %%
questions = ["Recommend me a summer dress for women",
             "Recommend me a cheap shirt for men",
             "What is the price for the product BR470",
             "What is the product Open-weave packable straw hat for women made of",
             "What size does BP771 have"]
for question in questions:
    docs = retriever.get_relevant_documents(question)
    print(question)
    print("\n\n".join([x.page_content[:200] for x in docs[:2]]))
    print("\n\n\n")
# Out:
# Recommend me a summer dress for women
# mini length. Plus, this dress is made with a lightweight, super-breathable linen (aka our version of personal AC).
#
# BR470 is J.Crew: Maxine V-neck shift dress in linen for women
# BR470 is for women
# BR470 costs $118.00
#
#
#
#
# Recommend me a cheap shirt for men
# BE981 is J.Crew: Short-sleeve seersucker shirt in print for men
# BE981 is for men
# BE981 costs $79.50
#
# BJ706 is J.Crew: Secret Wash cotton poplin shirt for men
# BJ706 is for men
# BJ706 costs $89.50
#
#
#
#
# What is the price for the product BR470
# BR470 is J.Crew: Maxine V-neck shift dress in linen for women
# BR470 is for women
# BR470 costs $118.00
#
# BR470 : 100% linen.
# BR470 : Lined.
# BR470 : Machine wash.
# BR470 : Import.
# BR470 has Sheath silhouette.
# BR470 has Falls above knee, 38 1/2" from high point of shoulder (based on a size 6).
#
#
#
#
# What is the product Open-weave packable straw hat for women made of
# BH859 is J.Crew: Open-weave packable straw hat for women
# BH859 is for women
# BH859 costs $69.50
#
# For BH859, A cool open weave makes this raffia style the perfect, breezy addition to every sunny day. Plus, it bounces back easily after a trip in your suitcase, carry-on or beach bag.
#
#
#
#
# What size does BP771 have
# BP771 : 100% cotton.
# BP771 : Machine wash.
# BP771 : Import.
# BP771 : Select stores.
# BP771 has Body length: 23 1/4".
# BP771 has color WHITE, and NAVY, and
#
# BP771 has size 3X, andMEDIUM, andXX-SMALL, and2X, andX-LARGE, andSMALL, andXX-LARGE, andLARGE, andX-SMALL, and
